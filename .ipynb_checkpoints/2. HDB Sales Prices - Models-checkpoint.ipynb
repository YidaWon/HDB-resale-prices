# %% [markdown]
# # HDB resale flat prices
#
# Objective: To build a model that can predict prices in  5 - 10 years time, and find out what are the key factors driving house resale prices.

# %% [markdown]
# <b>Content:</b>
# 1. Load Data
#
# 2. Feature Engineering
#
# <b>Models used:</b>
# 3. Elastic Net Regression (Linear approach)
#
# 4. Random Forest Regressor (Tree based approach)
#
# 5. Time Series Analysis and Predictions

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %matplotlib inline

# %% [markdown]
# ### 1. Load Data

# %%
data = pd.read_csv('./data/adjusted_data.csv')

# %%
data
# Out:
#         month        town         flat_type block        street_name  \
# 0           1  ANG MO KIO            3 ROOM   216   ANG MO KIO AVE 1
# 1           1  ANG MO KIO            4 ROOM   304   ANG MO KIO AVE 1
# 2           1  ANG MO KIO            5 ROOM   306   ANG MO KIO AVE 1
# 3           1  ANG MO KIO            3 ROOM   332   ANG MO KIO AVE 1
# 4           1  ANG MO KIO            4 ROOM   336   ANG MO KIO AVE 1
# 5           1  ANG MO KIO            4 ROOM   335   ANG MO KIO AVE 1
# 6           1  ANG MO KIO            3 ROOM   418  ANG MO KIO AVE 10
# 7           1  ANG MO KIO            3 ROOM   440  ANG MO KIO AVE 10
# 8           1  ANG MO KIO            3 ROOM   432  ANG MO KIO AVE 10
# 9           1  ANG MO KIO            4 ROOM   470  ANG MO KIO AVE 10
# 10          1  ANG MO KIO            4 ROOM   472  ANG MO KIO AVE 10
# 11          1  ANG MO KIO            4 ROOM   476  ANG MO KIO AVE 10
# 12          1  ANG MO KIO            3 ROOM   474  ANG MO KIO AVE 10
# 13          1  ANG MO KIO            3 ROOM   456  ANG MO KIO AVE 10
# 14          1  ANG MO KIO            5 ROOM   460  ANG MO KIO AVE 10
# 15          1  ANG MO KIO            3 ROOM   462  ANG MO KIO AVE 10
# 16          1  ANG MO KIO            4 ROOM   560  ANG MO KIO AVE 10
# 17          1  ANG MO KIO            3 ROOM   558  ANG MO KIO AVE 10
# 18          1  ANG MO KIO            3 ROOM   557  ANG MO KIO AVE 10
# 19          1  ANG MO KIO            3 ROOM   534  ANG MO KIO AVE 10
# 20          1  ANG MO KIO            3 ROOM   536  ANG MO KIO AVE 10
# 21          1  ANG MO KIO            3 ROOM   541  ANG MO KIO AVE 10
# 22          1  ANG MO KIO            3 ROOM   542  ANG MO KIO AVE 10
# 23          1  ANG MO KIO            3 ROOM   550  ANG MO KIO AVE 10
# 24          1  ANG MO KIO            3 ROOM   550  ANG MO KIO AVE 10
# 25          1  ANG MO KIO            3 ROOM   561  ANG MO KIO AVE 10
# 26          1  ANG MO KIO            2 ROOM   406  ANG MO KIO AVE 10
# 27          1  ANG MO KIO            3 ROOM   558  ANG MO KIO AVE 10
# 28          1  ANG MO KIO            3 ROOM   214   ANG MO KIO AVE 3
# 29          1  ANG MO KIO            4 ROOM   209   ANG MO KIO AVE 3
# ...       ...         ...               ...   ...                ...
# 130853     10      YISHUN            4 ROOM   735       YISHUN ST 72
# 130854     10      YISHUN            4 ROOM   758       YISHUN ST 72
# 130855     10      YISHUN            4 ROOM   756       YISHUN ST 72
# 130856     10      YISHUN            4 ROOM   820       YISHUN ST 81
# 130857     10      YISHUN            4 ROOM   873       YISHUN ST 81
# 130858     10      YISHUN            5 ROOM  348D      YISHUN AVE 11
# 130859     10      YISHUN            5 ROOM  426A      YISHUN AVE 11
# 130860     10      YISHUN            5 ROOM  426A      YISHUN AVE 11
# 130861     10      YISHUN            5 ROOM  426C      YISHUN AVE 11
# 130862     10      YISHUN            5 ROOM  426D      YISHUN AVE 11
# 130863     10      YISHUN            5 ROOM   657       YISHUN AVE 4
# 130864     10      YISHUN            5 ROOM   858       YISHUN AVE 4
# 130865     10      YISHUN            5 ROOM   733       YISHUN AVE 5
# 130866     10      YISHUN            5 ROOM   288       YISHUN AVE 6
# 130867     10      YISHUN            5 ROOM   928      YISHUN CTRL 1
# 130868     10      YISHUN            5 ROOM   331     YISHUN RING RD
# 130869     10      YISHUN            5 ROOM   619     YISHUN RING RD
# 130870     10      YISHUN            5 ROOM   357     YISHUN RING RD
# 130871     10      YISHUN            5 ROOM   156       YISHUN ST 11
# 130872     10      YISHUN            5 ROOM   161       YISHUN ST 11
# 130873     10      YISHUN            5 ROOM  336C       YISHUN ST 31
# 130874     10      YISHUN            5 ROOM   865       YISHUN ST 81
# 130875     10      YISHUN            5 ROOM   866       YISHUN ST 81
# 130876     10      YISHUN            5 ROOM   880       YISHUN ST 81
# 130877     10      YISHUN            5 ROOM   865       YISHUN ST 81
# 130878     10      YISHUN         EXECUTIVE   324        YISHUN CTRL
# 130879     10      YISHUN         EXECUTIVE   293       YISHUN ST 22
# 130880     10      YISHUN         EXECUTIVE   723       YISHUN ST 71
# 130881     10      YISHUN  MULTI-GENERATION   666       YISHUN AVE 4
# 130882     10      YISHUN  MULTI-GENERATION   605       YISHUN ST 61
#
#        storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# 0          07 TO 09            73.0    NEW GENERATION                 1976
# 1          10 TO 12            97.0    NEW GENERATION                 1977
# 2          01 TO 03           123.0          STANDARD                 1977
# 3          10 TO 12            68.0    NEW GENERATION                 1981
# 4          07 TO 09            91.0    NEW GENERATION                 1982
# 5          01 TO 03            91.0    NEW GENERATION                 1982
# 6          04 TO 06            89.0    NEW GENERATION                 1979
# 7          10 TO 12            67.0    NEW GENERATION                 1979
# 8          07 TO 09            82.0    NEW GENERATION                 1979
# 9          04 TO 06            92.0    NEW GENERATION                 1979
# 10         10 TO 12            92.0    NEW GENERATION                 1979
# 11         10 TO 12            91.0    NEW GENERATION                 1979
# 12         10 TO 12            67.0    NEW GENERATION                 1984
# 13         07 TO 09            74.0    NEW GENERATION                 1980
# 14         10 TO 12           120.0          IMPROVED                 1980
# 15         01 TO 03            68.0    NEW GENERATION                 1980
# 16         04 TO 06            92.0    NEW GENERATION                 1980
# 17         10 TO 12            67.0    NEW GENERATION                 1980
# 18         07 TO 09            82.0    NEW GENERATION                 1980
# 19         04 TO 06            68.0    NEW GENERATION                 1980
# 20         04 TO 06            68.0    NEW GENERATION                 1980
# 21         01 TO 03            68.0    NEW GENERATION                 1981
# 22         07 TO 09            68.0    NEW GENERATION                 1981
# 23         10 TO 12            82.0    NEW GENERATION                 1981
# 24         10 TO 12            68.0    NEW GENERATION                 1981
# 25         07 TO 09            68.0    NEW GENERATION                 1980
# 26         01 TO 03            44.0          IMPROVED                 1979
# 27         10 TO 12            67.0    NEW GENERATION                 1980
# 28         04 TO 06            67.0    NEW GENERATION                 1976
# 29         07 TO 09            91.0    NEW GENERATION                 1977
# ...             ...             ...               ...                  ...
# 130853     04 TO 06            93.0    NEW GENERATION                 1985
# 130854     07 TO 09            84.0        SIMPLIFIED                 1986
# 130855     10 TO 12            84.0        SIMPLIFIED                 1985
# 130856     10 TO 12           104.0           MODEL A                 1988
# 130857     10 TO 12           104.0           MODEL A                 1988
# 130858     01 TO 03           112.0              DBSS                 2013
# 130859     04 TO 06           112.0          IMPROVED                 2015
# 130860     01 TO 03           112.0          IMPROVED                 2015
# 130861     01 TO 03           112.0          IMPROVED                 2015
# 130862     07 TO 09           112.0          IMPROVED                 2015
# 130863     04 TO 06           121.0          IMPROVED                 1987
# 130864     07 TO 09           122.0          IMPROVED                 1988
# 130865     01 TO 03           121.0          IMPROVED                 1984
# 130866     01 TO 03           122.0          IMPROVED                 1987
# 130867     04 TO 06           123.0          IMPROVED                 1993
# 130868     07 TO 09           122.0          IMPROVED                 1988
# 130869     10 TO 12           121.0          IMPROVED                 1987
# 130870     10 TO 12           122.0          IMPROVED                 1988
# 130871     01 TO 03           134.0     ADJOINED FLAT                 1985
# 130872     07 TO 09           126.0          IMPROVED                 1985
# 130873     10 TO 12           112.0          IMPROVED                 2015
# 130874     10 TO 12           127.0          IMPROVED                 1988
# 130875     10 TO 12           127.0          IMPROVED                 1988
# 130876     04 TO 06           122.0          IMPROVED                 1988
# 130877     10 TO 12           127.0          IMPROVED                 1988
# 130878     07 TO 09           142.0         APARTMENT                 1988
# 130879     01 TO 03           163.0         APARTMENT                 1992
# 130880     01 TO 03           142.0         APARTMENT                 1986
# 130881     07 TO 09           179.0  MULTI GENERATION                 1987
# 130882     01 TO 03           163.0  MULTI GENERATION                 1988
#
#         remaining_lease  resale_price        date  year  gdp_per_capita
# 0                    63      340551.0  2012-01-01  2012           54431
# 1                    64      472231.0  2012-01-01  2012           54431
# 2                    64      508556.0  2012-01-01  2012           54431
# 3                    68      317848.0  2012-01-01  2012           54431
# 4                    69      435905.0  2012-01-01  2012           54431
# 5                    69      417743.0  2012-01-01  2012           54431
# 6                    66      381417.0  2012-01-01  2012           54431
# 7                    66      313307.0  2012-01-01  2012           54431
# 8                    66      336010.0  2012-01-01  2012           54431
# 9                    66      395039.0  2012-01-01  2012           54431
# 10                   66      392133.0  2012-01-01  2012           54431
# 11                   66      408661.0  2012-01-01  2012           54431
# 12                   71      304226.0  2012-01-01  2012           54431
# 13                   67      308766.0  2012-01-01  2012           54431
# 14                   67      527627.0  2012-01-01  2012           54431
# 15                   67      290604.0  2012-01-01  2012           54431
# 16                   67      399580.0  2012-01-01  2012           54431
# 17                   67      305134.0  2012-01-01  2012           54431
# 18                   67      345092.0  2012-01-01  2012           54431
# 19                   67      310583.0  2012-01-01  2012           54431
# 20                   67      302409.0  2012-01-01  2012           54431
# 21                   68      299685.0  2012-01-01  2012           54431
# 22                   68      296961.0  2012-01-01  2012           54431
# 23                   68      371246.0  2012-01-01  2012           54431
# 24                   68      306950.0  2012-01-01  2012           54431
# 25                   67      315123.0  2012-01-01  2012           54431
# 26                   66      234118.0  2012-01-01  2012           54431
# 27                   67      312399.0  2012-01-01  2012           54431
# 28                   63      288787.0  2012-01-01  2012           54431
# 29                   64      440446.0  2012-01-01  2012           54431
# ...                 ...           ...         ...   ...             ...
# 130853               65      410000.0  2018-10-01  2018           55236
# 130854               67      335000.0  2018-10-01  2018           55236
# 130855               66      338000.0  2018-10-01  2018           55236
# 130856               68      380000.0  2018-10-01  2018           55236
# 130857               68      390000.0  2018-10-01  2018           55236
# 130858               94      655000.0  2018-10-01  2018           55236
# 130859               95      495000.0  2018-10-01  2018           55236
# 130860               95      450000.0  2018-10-01  2018           55236
# 130861               95      450000.0  2018-10-01  2018           55236
# 130862               95      495000.0  2018-10-01  2018           55236
# 130863               68      400000.0  2018-10-01  2018           55236
# 130864               68      465000.0  2018-10-01  2018           55236
# 130865               64      405000.0  2018-10-01  2018           55236
# 130866               67      398000.0  2018-10-01  2018           55236
# 130867               73      533888.0  2018-10-01  2018           55236
# 130868               69      408000.0  2018-10-01  2018           55236
# 130869               67      470000.0  2018-10-01  2018           55236
# 130870               68      440000.0  2018-10-01  2018           55236
# 130871               65      508000.0  2018-10-01  2018           55236
# 130872               65      451000.0  2018-10-01  2018           55236
# 130873               96      510888.0  2018-10-01  2018           55236
# 130874               68      535000.0  2018-10-01  2018           55236
# 130875               68      435000.0  2018-10-01  2018           55236
# 130876               68      410000.0  2018-10-01  2018           55236
# 130877               68      470000.0  2018-10-01  2018           55236
# 130878               68      508000.0  2018-10-01  2018           55236
# 130879               72      608000.0  2018-10-01  2018           55236
# 130880               66      450000.0  2018-10-01  2018           55236
# 130881               68      868000.0  2018-10-01  2018           55236
# 130882               68      660000.0  2018-10-01  2018           55236
#
# [130883 rows x 14 columns]

# %% [markdown]
# ### 2. Feature Engineering

# %%
#date and year will be dropped. Since the goal is to predict sales, predicting based on year of the sales is meaningless.
#block will also be dropped, we will use street_name to represent the general location of the flat.
df = data.drop(['block','street_name','date','year'], axis=1)

#Changing storey_range into ordinal features in ranges of 10 (1 - 9 will be 10, 10 to 19 will be 20 and so on.)
df['storey_range'] = df['storey_range'].apply(lambda x : (int(x[0])+1)*10)

#Month is a categorical variable
df['month'] = df['month'].astype(str)

#Getting dummies for categorical virables
df = pd.get_dummies(df, drop_first=True)

# %%
df.columns
# Out:
# Index(['storey_range', 'floor_area_sqm', 'lease_commence_date',
#        'remaining_lease', 'resale_price', 'gdp_per_capita', 'month_10',
#        'month_11', 'month_12', 'month_2', 'month_3', 'month_4', 'month_5',
#        'month_6', 'month_7', 'month_8', 'month_9', 'town_BEDOK', 'town_BISHAN',
#        'town_BUKIT BATOK', 'town_BUKIT MERAH', 'town_BUKIT PANJANG',
#        'town_BUKIT TIMAH', 'town_CENTRAL AREA', 'town_CHOA CHU KANG',
#        'town_CLEMENTI', 'town_GEYLANG', 'town_HOUGANG', 'town_JURONG EAST',
#        'town_JURONG WEST', 'town_KALLANG/WHAMPOA', 'town_MARINE PARADE',
#        'town_PASIR RIS', 'town_PUNGGOL', 'town_QUEENSTOWN', 'town_SEMBAWANG',
#        'town_SENGKANG', 'town_SERANGOON', 'town_TAMPINES', 'town_TOA PAYOH',
#        'town_WOODLANDS', 'town_YISHUN', 'flat_type_2 ROOM', 'flat_type_3 ROOM',
#        'flat_type_4 ROOM', 'flat_type_5 ROOM', 'flat_type_EXECUTIVE',
#        'flat_type_MULTI-GENERATION', 'flat_model_ADJOINED FLAT',
#        'flat_model_APARTMENT', 'flat_model_DBSS', 'flat_model_IMPROVED',
#        'flat_model_IMPROVED-MAISONETTE', 'flat_model_MAISONETTE',
#        'flat_model_MODEL A', 'flat_model_MODEL A-MAISONETTE',
#        'flat_model_MODEL A2', 'flat_model_MULTI GENERATION',
#        'flat_model_NEW GENERATION', 'flat_model_PREMIUM APARTMENT',
#        'flat_model_PREMIUM APARTMENT LOFT', 'flat_model_PREMIUM MAISONETTE',
#        'flat_model_SIMPLIFIED', 'flat_model_STANDARD', 'flat_model_TERRACE',
#        'flat_model_TYPE S1', 'flat_model_TYPE S2'],
#       dtype='object')

# %%
df.shape
# Out:
# (130883, 67)

# %% [markdown]
# ### 3. Linear Model

# %%
from sklearn.linear_model import LinearRegression, Ridge, RidgeCV, Lasso, ElasticNet, ElasticNetCV, LassoCV, LogisticRegression
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler

# %%
def eval_linear_model(model, X_train, y_train, X_test, y_test, cv=5):
    
    scores = cross_val_score(model, X_train, y_train, cv=cv)
    print("Cross-validated scores for train set:", scores)
    print("Mean cross-validated score:", scores.mean())
    
    #Fitting the model
    model = model.fit(X_train, y_train)
    print("R^2 Score for the test set:", model.score(X_test, y_test))
    
    '''
    #Predictions on the test dataset
    y_pred = pd.DataFrame(model.predict(X_test))  
    scatter = pd.DataFrame(list(zip(y_test,y_pred)),columns=['Actual Resales Price','Predicted Resales Price'])
    sns.scatterplot(x = 'Actual Resales Price', y = 'Predicted Resales Price', data = scatter)
    '''
            
    return model

# %%
#Defining function for getting important features
def impt_feat(coef, X_test):
    return pd.Series(coef, index=X_test.columns).sort_values(ascending=False)

# %%
#Defining train-test split
X = df.drop('resale_price',axis=1)
y = df['resale_price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=28)

# %%
#Scaling X
ss = StandardScaler()
Xs_train = ss.fit_transform(X_train)
Xs_test = ss.transform(X_test)
# Out:
# C:\Users\yitaris\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype uint8, int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\yitaris\Anaconda3\lib\site-packages\sklearn\base.py:462: DataConversionWarning: Data with input dtype uint8, int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# C:\Users\yitaris\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: Data with input dtype uint8, int64, float64 were all converted to float64 by StandardScaler.
#   after removing the cwd from sys.path.

# %%
enet = ElasticNetCV(l1_ratio=[.1, .5, .7, .9, .95, .99, 1], eps=0.001, n_alphas=500, cv=10, normalize=True, n_jobs=-1, verbose=2)
enmodel = enet.fit(Xs_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# Path: 000 out of 500
# Path: 000 out of 500
# Path: 001 out of 500
# Path: 001 out of 500Path: 000 out of 500
# Path: 000 out of 500Path: 002 out of 500Path: 000 out of 500
#
#
# Path: 000 out of 500
# Path: 000 out of 500
# Path: 001 out of 500
# Path: 003 out of 500Path: 002 out of 500
#
#
# Path: 000 out of 500Path: 001 out of 500Path: 001 out of 500Path: 001 out of 500
#
# Path: 002 out of 500
# Path: 001 out of 500
#
#
# Path: 004 out of 500Path: 001 out of 500Path: 003 out of 500
#
# Path: 002 out of 500Path: 002 out of 500
#
#
# Path: 002 out of 500
# Path: 003 out of 500Path: 005 out of 500Path: 002 out of 500Path: 004 out of 500
#
#
# Path: 002 out of 500
#
# Path: 003 out of 500
# Path: 003 out of 500Path: 003 out of 500
#
# Path: 006 out of 500Path: 003 out of 500
#
# Path: 003 out of 500
# Path: 004 out of 500
# Path: 004 out of 500Path: 004 out of 500Path: 004 out of 500Path: 004 out of 500Path: 005 out of 500
#
#
#
# Path: 007 out of 500
#
# Path: 004 out of 500
# Path: 005 out of 500Path: 005 out of 500Path: 005 out of 500
#
# Path: 005 out of 500Path: 005 out of 500Path: 006 out of 500
#
#
#
# Path: 008 out of 500
# Path: 005 out of 500Path: 006 out of 500
#
# Path: 006 out of 500Path: 006 out of 500Path: 006 out of 500
#
# Path: 007 out of 500
# Path: 006 out of 500
# Path: 009 out of 500
#
# Path: 007 out of 500Path: 007 out of 500
#
# Path: 006 out of 500Path: 007 out of 500Path: 007 out of 500
#
# Path: 008 out of 500Path: 010 out of 500
# Path: 007 out of 500
#
#
# Path: 007 out of 500Path: 008 out of 500Path: 008 out of 500
# Path: 008 out of 500
#
#
# Path: 008 out of 500Path: 011 out of 500Path: 008 out of 500
# Path: 008 out of 500
#
# Path: 009 out of 500
# Path: 009 out of 500
#
# Path: 012 out of 500Path: 009 out of 500Path: 009 out of 500
#
# Path: 009 out of 500
# Path: 009 out of 500
# Path: 009 out of 500
#
# Path: 010 out of 500Path: 013 out of 500
# Path: 010 out of 500
# Path: 010 out of 500
#
# Path: 010 out of 500Path: 010 out of 500Path: 011 out of 500Path: 010 out of 500Path: 010 out of 500
#
# Path: 014 out of 500
# Path: 011 out of 500
# Path: 011 out of 500
#
#
#
# Path: 011 out of 500Path: 012 out of 500
# Path: 011 out of 500
#
# Path: 015 out of 500Path: 012 out of 500Path: 012 out of 500
#
# Path: 012 out of 500Path: 012 out of 500Path: 011 out of 500Path: 011 out of 500
#
#
#
#
# Path: 013 out of 500Path: 013 out of 500
# Path: 013 out of 500
#
# Path: 016 out of 500Path: 013 out of 500
#
# Path: 012 out of 500Path: 014 out of 500
#
# Path: 012 out of 500Path: 013 out of 500Path: 014 out of 500Path: 014 out of 500
#
#
# Path: 017 out of 500
#
# Path: 013 out of 500Path: 015 out of 500
#
# Path: 015 out of 500Path: 014 out of 500
#
# Path: 013 out of 500Path: 014 out of 500Path: 018 out of 500Path: 015 out of 500
#
#
#
# Path: 016 out of 500Path: 016 out of 500Path: 015 out of 500Path: 014 out of 500
#
#
# Path: 014 out of 500
# Path: 019 out of 500Path: 015 out of 500Path: 016 out of 500
#
#
#
# Path: 017 out of 500Path: 016 out of 500
#
# Path: 016 out of 500Path: 017 out of 500Path: 015 out of 500
#
#
# Path: 017 out of 500Path: 015 out of 500Path: 020 out of 500
#
#
# Path: 017 out of 500Path: 018 out of 500
# Path: 018 out of 500
# Path: 016 out of 500
#
# Path: 017 out of 500Path: 021 out of 500Path: 018 out of 500Path: 016 out of 500
#
#
#
# Path: 018 out of 500Path: 019 out of 500Path: 019 out of 500
# Path: 022 out of 500
# Path: 018 out of 500
#
#
# Path: 017 out of 500Path: 017 out of 500
# Path: 019 out of 500
# Path: 019 out of 500
#
# Path: 023 out of 500Path: 018 out of 500Path: 020 out of 500Path: 020 out of 500Path: 019 out of 500
#
# Path: 018 out of 500
# Path: 020 out of 500
#
#
# Path: 020 out of 500
#
# Path: 019 out of 500Path: 021 out of 500
#
# Path: 021 out of 500Path: 024 out of 500Path: 020 out of 500Path: 021 out of 500Path: 021 out of 500
#
#
#
#
# Path: 019 out of 500Path: 020 out of 500Path: 022 out of 500
#
# Path: 022 out of 500Path: 022 out of 500
# Path: 025 out of 500
# Path: 021 out of 500
#
# Path: 023 out of 500
# Path: 020 out of 500Path: 022 out of 500Path: 023 out of 500
#
# Path: 022 out of 500
#
# Path: 021 out of 500
# Path: 026 out of 500
#
# Path: 024 out of 500Path: 023 out of 500
# Path: 027 out of 500Path: 024 out of 500Path: 021 out of 500
# Path: 023 out of 500
#
# Path: 023 out of 500
#
#
# Path: 025 out of 500Path: 025 out of 500Path: 022 out of 500Path: 022 out of 500Path: 028 out of 500Path: 024 out of 500
#
#
#
#
# Path: 024 out of 500
# Path: 024 out of 500
#
# Path: 026 out of 500Path: 025 out of 500Path: 023 out of 500
#
#
# Path: 025 out of 500Path: 026 out of 500Path: 029 out of 500
# Path: 023 out of 500
# Path: 025 out of 500Path: 026 out of 500
# Path: 027 out of 500
#
#
#
# Path: 027 out of 500Path: 024 out of 500Path: 030 out of 500Path: 026 out of 500
# Path: 024 out of 500
#
#
# Path: 028 out of 500
# Path: 027 out of 500
#
# Path: 028 out of 500Path: 026 out of 500
#
# Path: 031 out of 500Path: 027 out of 500
#
# Path: 029 out of 500Path: 025 out of 500
# Path: 025 out of 500Path: 029 out of 500Path: 027 out of 500
#
#
# Path: 028 out of 500Path: 028 out of 500Path: 032 out of 500
#
#
#
# Path: 030 out of 500
# Path: 026 out of 500Path: 030 out of 500
#
# Path: 029 out of 500
# Path: 033 out of 500Path: 029 out of 500Path: 028 out of 500Path: 026 out of 500Path: 031 out of 500
#
#
#
#
# Path: 029 out of 500Path: 031 out of 500Path: 030 out of 500Path: 027 out of 500
#
#
#
# Path: 032 out of 500
# Path: 027 out of 500Path: 030 out of 500
#
# Path: 032 out of 500Path: 033 out of 500Path: 030 out of 500
#
# Path: 031 out of 500Path: 034 out of 500
# Path: 028 out of 500
#
#
# Path: 028 out of 500Path: 031 out of 500
# Path: 034 out of 500Path: 033 out of 500Path: 032 out of 500
# Path: 029 out of 500Path: 031 out of 500
#
#
#
#
# Path: 029 out of 500
# Path: 035 out of 500Path: 034 out of 500
#
# Path: 036 out of 500Path: 032 out of 500Path: 030 out of 500Path: 033 out of 500
# Path: 032 out of 500Path: 035 out of 500
# Path: 030 out of 500Path: 035 out of 500
#
#
#
#
#
# Path: 033 out of 500Path: 034 out of 500
# Path: 031 out of 500
# Path: 036 out of 500
#
# Path: 037 out of 500Path: 036 out of 500Path: 033 out of 500Path: 035 out of 500
#
#
# Path: 031 out of 500
#
# Path: 037 out of 500
# Path: 034 out of 500Path: 037 out of 500
#
# Path: 034 out of 500Path: 038 out of 500
# Path: 032 out of 500Path: 036 out of 500
#
# Path: 032 out of 500
#
# Path: 038 out of 500Path: 038 out of 500Path: 035 out of 500
# Path: 039 out of 500
#
# Path: 035 out of 500
# Path: 033 out of 500
#
# Path: 036 out of 500Path: 037 out of 500
# Path: 033 out of 500
#
# Path: 040 out of 500Path: 039 out of 500
# Path: 039 out of 500
#
# Path: 037 out of 500Path: 038 out of 500Path: 034 out of 500
#
#
# Path: 036 out of 500Path: 041 out of 500Path: 034 out of 500
# Path: 039 out of 500
# Path: 038 out of 500
#
# Path: 035 out of 500
# Path: 040 out of 500
# Path: 040 out of 500
#
# Path: 035 out of 500Path: 042 out of 500
#
# Path: 037 out of 500
# Path: 041 out of 500
# Path: 039 out of 500Path: 036 out of 500
# Path: 041 out of 500
# Path: 040 out of 500Path: 036 out of 500
#
#
# Path: 043 out of 500Path: 038 out of 500
# Path: 042 out of 500
# Path: 042 out of 500Path: 040 out of 500Path: 041 out of 500
# Path: 037 out of 500
#
#
#
# Path: 037 out of 500Path: 043 out of 500Path: 039 out of 500Path: 044 out of 500
#
#
#
# Path: 043 out of 500Path: 038 out of 500
#
# Path: 041 out of 500Path: 042 out of 500Path: 038 out of 500Path: 045 out of 500
#
#
#
# Path: 040 out of 500Path: 044 out of 500
#
# Path: 044 out of 500
# Path: 039 out of 500
# Path: 043 out of 500Path: 042 out of 500Path: 041 out of 500Path: 045 out of 500
#
#
#
# Path: 039 out of 500
# Path: 045 out of 500Path: 046 out of 500
#
# Path: 040 out of 500Path: 044 out of 500Path: 043 out of 500
#
#
# Path: 046 out of 500Path: 040 out of 500Path: 046 out of 500Path: 042 out of 500
#
#
#
# Path: 044 out of 500Path: 047 out of 500
# Path: 041 out of 500
# Path: 045 out of 500Path: 047 out of 500
#
#
# Path: 041 out of 500Path: 043 out of 500
#
# Path: 047 out of 500Path: 046 out of 500
#
# Path: 045 out of 500Path: 042 out of 500Path: 048 out of 500
# Path: 048 out of 500
#
# Path: 042 out of 500Path: 044 out of 500
#
# Path: 046 out of 500Path: 047 out of 500
#
#
# Path: 048 out of 500
# Path: 049 out of 500Path: 049 out of 500Path: 043 out of 500
# Path: 043 out of 500Path: 047 out of 500Path: 048 out of 500
#
#
#
#
# Path: 045 out of 500
# Path: 049 out of 500Path: 050 out of 500Path: 044 out of 500Path: 050 out of 500
# Path: 049 out of 500Path: 044 out of 500
#
#
#
#
# Path: 048 out of 500
# Path: 051 out of 500Path: 046 out of 500
# Path: 045 out of 500Path: 051 out of 500
#
#
# Path: 050 out of 500Path: 049 out of 500
#
# Path: 045 out of 500Path: 047 out of 500
# Path: 050 out of 500
#
# Path: 052 out of 500Path: 046 out of 500
# Path: 050 out of 500
# Path: 051 out of 500Path: 051 out of 500
# Path: 048 out of 500
#
#
# Path: 052 out of 500Path: 046 out of 500
#
# Path: 052 out of 500Path: 052 out of 500
#
# Path: 053 out of 500Path: 047 out of 500Path: 051 out of 500
#
#
# Path: 047 out of 500Path: 053 out of 500Path: 049 out of 500
#
# Path: 053 out of 500
#
# Path: 052 out of 500Path: 054 out of 500Path: 048 out of 500Path: 053 out of 500
#
#
#
# Path: 054 out of 500
# Path: 048 out of 500Path: 050 out of 500Path: 055 out of 500Path: 054 out of 500Path: 053 out of 500
#
#
#
#
# Path: 054 out of 500Path: 049 out of 500
# Path: 055 out of 500
# Path: 056 out of 500
# Path: 051 out of 500Path: 054 out of 500
# Path: 055 out of 500
#
# Path: 049 out of 500
# Path: 050 out of 500
# Path: 055 out of 500
# Path: 057 out of 500
#
# Path: 052 out of 500
# Path: 056 out of 500Path: 056 out of 500
# Path: 055 out of 500Path: 051 out of 500Path: 056 out of 500
#
#
#
# Path: 050 out of 500Path: 058 out of 500
# Path: 057 out of 500
#
# Path: 053 out of 500
# Path: 052 out of 500Path: 057 out of 500Path: 056 out of 500Path: 057 out of 500
#
#
# Path: 058 out of 500
#
# Path: 051 out of 500
# Path: 054 out of 500Path: 059 out of 500
# Path: 058 out of 500Path: 057 out of 500Path: 058 out of 500Path: 059 out of 500
#
#
#
#
# Path: 053 out of 500
# Path: 058 out of 500Path: 059 out of 500
# Path: 059 out of 500
# Path: 052 out of 500
# Path: 060 out of 500
# Path: 060 out of 500Path: 055 out of 500Path: 054 out of 500
#
#
#
# Path: 059 out of 500Path: 060 out of 500
# Path: 060 out of 500
# Path: 061 out of 500
# Path: 055 out of 500Path: 061 out of 500Path: 056 out of 500
#
#
# Path: 053 out of 500
#
# Path: 060 out of 500Path: 061 out of 500
# Path: 056 out of 500Path: 062 out of 500Path: 061 out of 500
# Path: 062 out of 500
#
#
# Path: 054 out of 500
#
# Path: 057 out of 500
# Path: 057 out of 500
# Path: 062 out of 500Path: 061 out of 500
#
# Path: 063 out of 500Path: 062 out of 500
# Path: 063 out of 500Path: 058 out of 500Path: 063 out of 500
#
#
#
# Path: 055 out of 500Path: 058 out of 500
# Path: 062 out of 500
#
# Path: 064 out of 500Path: 063 out of 500Path: 064 out of 500
#
#
# Path: 064 out of 500Path: 056 out of 500
# Path: 059 out of 500
#
# Path: 065 out of 500Path: 065 out of 500Path: 059 out of 500
#
# Path: 063 out of 500Path: 064 out of 500
#
# Path: 057 out of 500Path: 065 out of 500
#
#
# Path: 066 out of 500Path: 064 out of 500Path: 066 out of 500
# Path: 060 out of 500
# Path: 060 out of 500
# Path: 066 out of 500Path: 065 out of 500
#
#
#
# Path: 058 out of 500Path: 065 out of 500
# Path: 061 out of 500
#
# Path: 067 out of 500Path: 067 out of 500
# Path: 061 out of 500Path: 067 out of 500Path: 066 out of 500
#
#
#
# Path: 066 out of 500Path: 062 out of 500
# Path: 068 out of 500Path: 059 out of 500
#
# Path: 062 out of 500
#
# Path: 068 out of 500Path: 067 out of 500
#
# Path: 060 out of 500Path: 068 out of 500
# Path: 063 out of 500
# Path: 069 out of 500
#
# Path: 067 out of 500Path: 068 out of 500Path: 063 out of 500
#
#
# Path: 061 out of 500Path: 069 out of 500
#
# Path: 070 out of 500Path: 069 out of 500Path: 069 out of 500
#
#
# Path: 064 out of 500Path: 068 out of 500Path: 062 out of 500
#
#
# Path: 064 out of 500Path: 070 out of 500Path: 071 out of 500
#
#
# Path: 065 out of 500Path: 070 out of 500
#
# Path: 069 out of 500Path: 063 out of 500
#
# Path: 070 out of 500Path: 065 out of 500Path: 071 out of 500Path: 072 out of 500
#
#
# Path: 066 out of 500
# Path: 071 out of 500
# Path: 070 out of 500
#
# Path: 066 out of 500Path: 071 out of 500
# Path: 072 out of 500
# Path: 073 out of 500
# Path: 072 out of 500
#
# Path: 067 out of 500Path: 064 out of 500Path: 071 out of 500
#
# Path: 073 out of 500Path: 067 out of 500Path: 072 out of 500
#
# Path: 074 out of 500
#
# Path: 073 out of 500
# Path: 065 out of 500
#
# Path: 072 out of 500Path: 073 out of 500Path: 074 out of 500
#
#
# Path: 068 out of 500
# Path: 075 out of 500Path: 066 out of 500
#
# Path: 074 out of 500Path: 068 out of 500Path: 073 out of 500
# Path: 075 out of 500Path: 069 out of 500
# Path: 074 out of 500
#
# Path: 074 out of 500Path: 069 out of 500Path: 067 out of 500
#
#
# Path: 076 out of 500Path: 075 out of 500
#
# Path: 070 out of 500Path: 075 out of 500Path: 076 out of 500Path: 070 out of 500Path: 068 out of 500
#
#
#
#
# Path: 075 out of 500
# Path: 076 out of 500Path: 077 out of 500
#
# Path: 077 out of 500Path: 076 out of 500
#
# Path: 071 out of 500Path: 069 out of 500Path: 071 out of 500
# Path: 076 out of 500
#
#
# Path: 078 out of 500Path: 078 out of 500
#
# Path: 072 out of 500Path: 077 out of 500
# Path: 070 out of 500
# Path: 077 out of 500
# Path: 072 out of 500
#
# Path: 079 out of 500Path: 079 out of 500Path: 077 out of 500
# Path: 073 out of 500
#
#
# Path: 078 out of 500Path: 073 out of 500Path: 078 out of 500
#
#
# Path: 080 out of 500Path: 071 out of 500Path: 078 out of 500Path: 080 out of 500Path: 074 out of 500
# Path: 079 out of 500
#
#
#
#
# Path: 079 out of 500Path: 081 out of 500
#
# Path: 072 out of 500Path: 081 out of 500Path: 074 out of 500Path: 080 out of 500
# Path: 079 out of 500Path: 075 out of 500
#
#
#
#
# Path: 082 out of 500Path: 073 out of 500Path: 080 out of 500
#
#
# Path: 082 out of 500
# Path: 076 out of 500
# Path: 080 out of 500Path: 081 out of 500Path: 075 out of 500Path: 081 out of 500
#
#
# Path: 074 out of 500Path: 083 out of 500
#
#
# Path: 083 out of 500Path: 077 out of 500
#
# Path: 076 out of 500Path: 081 out of 500Path: 082 out of 500
#
# Path: 084 out of 500Path: 082 out of 500Path: 084 out of 500
#
#
# Path: 078 out of 500
#
# Path: 082 out of 500Path: 075 out of 500
# Path: 077 out of 500Path: 083 out of 500Path: 085 out of 500
#
#
#
# Path: 085 out of 500Path: 079 out of 500
# Path: 083 out of 500
# Path: 083 out of 500
#
# Path: 076 out of 500Path: 078 out of 500Path: 084 out of 500Path: 086 out of 500
#
#
# Path: 080 out of 500Path: 086 out of 500Path: 084 out of 500
#
#
# Path: 084 out of 500
#
# Path: 079 out of 500
# Path: 085 out of 500Path: 087 out of 500Path: 087 out of 500
# Path: 085 out of 500
#
#
# Path: 081 out of 500Path: 085 out of 500
#
# Path: 080 out of 500Path: 077 out of 500Path: 086 out of 500Path: 088 out of 500
#
#
#
# Path: 086 out of 500
# Path: 086 out of 500Path: 088 out of 500Path: 089 out of 500
# Path: 082 out of 500
# Path: 081 out of 500
# Path: 078 out of 500Path: 087 out of 500
#
#
#
# Path: 087 out of 500
# Path: 087 out of 500Path: 089 out of 500Path: 088 out of 500
#
#
# Path: 079 out of 500Path: 082 out of 500Path: 083 out of 500
#
#
# Path: 090 out of 500Path: 088 out of 500Path: 088 out of 500
#
#
# Path: 090 out of 500Path: 089 out of 500
# Path: 083 out of 500
# Path: 091 out of 500Path: 089 out of 500
#
# Path: 080 out of 500
# Path: 084 out of 500
#
# Path: 089 out of 500
# Path: 091 out of 500Path: 092 out of 500Path: 090 out of 500
# Path: 084 out of 500Path: 081 out of 500
# Path: 090 out of 500
#
#
#
# Path: 085 out of 500Path: 090 out of 500Path: 093 out of 500
#
# Path: 085 out of 500Path: 092 out of 500Path: 091 out of 500
#
#
#
# Path: 082 out of 500Path: 091 out of 500
# Path: 091 out of 500
#
# Path: 092 out of 500Path: 086 out of 500
#
# Path: 086 out of 500Path: 094 out of 500Path: 093 out of 500Path: 083 out of 500
# Path: 092 out of 500
#
#
#
# Path: 092 out of 500
# Path: 087 out of 500
# Path: 093 out of 500
# Path: 087 out of 500Path: 084 out of 500Path: 093 out of 500Path: 094 out of 500Path: 095 out of 500
#
#
#
#
# Path: 088 out of 500
# Path: 093 out of 500Path: 094 out of 500Path: 088 out of 500Path: 096 out of 500Path: 094 out of 500
# Path: 085 out of 500
#
# Path: 095 out of 500
#
#
# Path: 089 out of 500
#
# Path: 095 out of 500
# Path: 097 out of 500Path: 094 out of 500Path: 095 out of 500Path: 086 out of 500Path: 089 out of 500
#
#
#
# Path: 096 out of 500
# Path: 090 out of 500
#
# Path: 098 out of 500Path: 087 out of 500Path: 096 out of 500Path: 090 out of 500
# Path: 095 out of 500
#
#
#
# Path: 096 out of 500Path: 091 out of 500
#
# Path: 097 out of 500Path: 097 out of 500Path: 091 out of 500Path: 097 out of 500
#
#
# Path: 092 out of 500Path: 088 out of 500
# Path: 099 out of 500
#
# Path: 096 out of 500
#
# Path: 092 out of 500Path: 098 out of 500
#
# Path: 098 out of 500Path: 098 out of 500Path: 089 out of 500Path: 100 out of 500
#
#
# Path: 093 out of 500
# Path: 097 out of 500Path: 093 out of 500Path: 099 out of 500
#
#
# Path: 099 out of 500Path: 101 out of 500
#
#
# Path: 099 out of 500Path: 090 out of 500
#
# Path: 094 out of 500
# Path: 098 out of 500Path: 094 out of 500Path: 100 out of 500
#
#
# Path: 102 out of 500Path: 100 out of 500Path: 091 out of 500
#
#
# Path: 100 out of 500
# Path: 099 out of 500Path: 101 out of 500
#
# Path: 092 out of 500Path: 095 out of 500Path: 101 out of 500
#
# Path: 095 out of 500
# Path: 103 out of 500Path: 101 out of 500
# Path: 100 out of 500
#
#
# Path: 102 out of 500Path: 096 out of 500
# Path: 093 out of 500
# Path: 102 out of 500
# Path: 104 out of 500
# Path: 096 out of 500Path: 101 out of 500Path: 102 out of 500
#
#
#
# Path: 103 out of 500Path: 097 out of 500
# Path: 094 out of 500
#
# Path: 103 out of 500
# Path: 104 out of 500Path: 105 out of 500Path: 102 out of 500Path: 103 out of 500Path: 097 out of 500
#
# Path: 095 out of 500
#
#
#
# Path: 098 out of 500
# Path: 104 out of 500Path: 103 out of 500Path: 105 out of 500
# Path: 098 out of 500
# Path: 106 out of 500Path: 104 out of 500
#
# Path: 099 out of 500
#
#
# Path: 096 out of 500
# Path: 099 out of 500Path: 105 out of 500
# Path: 106 out of 500Path: 100 out of 500Path: 104 out of 500Path: 105 out of 500Path: 107 out of 500
#
#
#
#
#
# Path: 097 out of 500Path: 106 out of 500
#
# Path: 107 out of 500Path: 105 out of 500Path: 106 out of 500Path: 101 out of 500Path: 108 out of 500
#
#
# Path: 100 out of 500
#
#
# Path: 107 out of 500Path: 106 out of 500Path: 108 out of 500
# Path: 101 out of 500
#
# Path: 098 out of 500
# Path: 109 out of 500
# Path: 102 out of 500
# Path: 107 out of 500
# Path: 107 out of 500
#
# Path: 108 out of 500Path: 109 out of 500
#
# Path: 099 out of 500Path: 103 out of 500Path: 102 out of 500Path: 110 out of 500Path: 108 out of 500
#
#
#
#
# Path: 108 out of 500Path: 109 out of 500Path: 110 out of 500Path: 103 out of 500Path: 100 out of 500
#
#
#
# Path: 111 out of 500Path: 109 out of 500
#
#
# Path: 104 out of 500
# Path: 104 out of 500Path: 109 out of 500
# Path: 111 out of 500
#
# Path: 101 out of 500Path: 112 out of 500Path: 110 out of 500
#
#
# Path: 110 out of 500
# Path: 105 out of 500Path: 112 out of 500Path: 110 out of 500
# Path: 105 out of 500
#
#
# Path: 111 out of 500Path: 111 out of 500Path: 102 out of 500
# Path: 111 out of 500
# Path: 106 out of 500
# Path: 106 out of 500
# Path: 113 out of 500
#
#
# Path: 113 out of 500
# Path: 112 out of 500Path: 103 out of 500Path: 107 out of 500Path: 107 out of 500
#
# Path: 112 out of 500
#
#
# Path: 112 out of 500Path: 114 out of 500Path: 114 out of 500
#
# Path: 113 out of 500
#
# Path: 108 out of 500Path: 104 out of 500Path: 108 out of 500
#
#
# Path: 113 out of 500Path: 114 out of 500Path: 115 out of 500Path: 115 out of 500
# Path: 113 out of 500
#
#
#
# Path: 109 out of 500Path: 109 out of 500Path: 114 out of 500Path: 115 out of 500Path: 105 out of 500
# Path: 114 out of 500
#
#
#
# Path: 116 out of 500
# Path: 116 out of 500
#
# Path: 106 out of 500Path: 110 out of 500
#
# Path: 115 out of 500Path: 116 out of 500
# Path: 115 out of 500Path: 117 out of 500Path: 110 out of 500
#
#
#
# Path: 107 out of 500Path: 111 out of 500
# Path: 116 out of 500
# Path: 117 out of 500
# Path: 116 out of 500
# Path: 118 out of 500Path: 108 out of 500
#
# Path: 111 out of 500Path: 117 out of 500
#
#
# Path: 117 out of 500Path: 117 out of 500Path: 118 out of 500Path: 119 out of 500
#
#
#
# Path: 112 out of 500
# Path: 109 out of 500Path: 119 out of 500Path: 118 out of 500Path: 118 out of 500
# Path: 118 out of 500
#
# Path: 112 out of 500
#
# Path: 120 out of 500Path: 113 out of 500
#
#
# Path: 110 out of 500Path: 119 out of 500Path: 120 out of 500Path: 113 out of 500
# Path: 119 out of 500Path: 119 out of 500
#
#
#
#
# Path: 121 out of 500
# Path: 111 out of 500Path: 120 out of 500Path: 121 out of 500
# Path: 120 out of 500Path: 114 out of 500
# Path: 120 out of 500
#
# Path: 114 out of 500
# Path: 122 out of 500
#
# Path: 112 out of 500Path: 122 out of 500
# Path: 121 out of 500
#
# Path: 121 out of 500
# Path: 115 out of 500
# Path: 123 out of 500
# Path: 115 out of 500
#
# Path: 123 out of 500Path: 122 out of 500
# Path: 113 out of 500
# Path: 116 out of 500
# Path: 124 out of 500Path: 116 out of 500
# Path: 122 out of 500Path: 121 out of 500
#
#
#
# Path: 124 out of 500Path: 114 out of 500
#
# Path: 125 out of 500Path: 123 out of 500Path: 117 out of 500Path: 117 out of 500
#
# Path: 122 out of 500
#
#
# Path: 123 out of 500Path: 115 out of 500
# Path: 118 out of 500Path: 126 out of 500
# Path: 125 out of 500
# Path: 124 out of 500Path: 118 out of 500
#
#
#
# Path: 123 out of 500
# Path: 116 out of 500
# Path: 119 out of 500Path: 124 out of 500
# Path: 125 out of 500
# Path: 126 out of 500Path: 124 out of 500
#
# Path: 119 out of 500Path: 127 out of 500
#
#
# Path: 125 out of 500Path: 120 out of 500
#
# Path: 117 out of 500Path: 126 out of 500Path: 125 out of 500
#
#
# Path: 120 out of 500Path: 128 out of 500
# Path: 121 out of 500
#
# Path: 126 out of 500Path: 127 out of 500Path: 127 out of 500Path: 118 out of 500
# Path: 122 out of 500
# Path: 121 out of 500Path: 126 out of 500
#
#
#
#
# Path: 129 out of 500
# Path: 122 out of 500Path: 119 out of 500
# Path: 127 out of 500
# Path: 123 out of 500Path: 127 out of 500Path: 128 out of 500
#
#
#
# Path: 128 out of 500
# Path: 130 out of 500
# Path: 129 out of 500Path: 128 out of 500Path: 123 out of 500Path: 120 out of 500
# Path: 128 out of 500
# Path: 129 out of 500Path: 124 out of 500
#
#
#
#
# Path: 130 out of 500Path: 121 out of 500Path: 130 out of 500Path: 131 out of 500Path: 124 out of 500
#
#
#
#
# Path: 125 out of 500Path: 129 out of 500Path: 129 out of 500
#
#
# Path: 131 out of 500Path: 132 out of 500
# Path: 122 out of 500
# Path: 131 out of 500
# Path: 130 out of 500Path: 125 out of 500Path: 126 out of 500
#
#
#
# Path: 130 out of 500Path: 132 out of 500
# Path: 123 out of 500Path: 132 out of 500
# Path: 131 out of 500
#
# Path: 126 out of 500Path: 133 out of 500Path: 133 out of 500Path: 131 out of 500
#
# Path: 124 out of 500
# Path: 132 out of 500Path: 127 out of 500
#
#
# Path: 133 out of 500
#
# Path: 134 out of 500Path: 132 out of 500
#
# Path: 133 out of 500
# Path: 125 out of 500Path: 128 out of 500Path: 134 out of 500Path: 135 out of 500
#
# Path: 134 out of 500
# Path: 127 out of 500
#
#
# Path: 133 out of 500
# Path: 129 out of 500Path: 134 out of 500Path: 135 out of 500
#
#
# Path: 136 out of 500
# Path: 126 out of 500Path: 135 out of 500Path: 128 out of 500Path: 134 out of 500
# Path: 130 out of 500
#
#
# Path: 137 out of 500
# Path: 136 out of 500
#
# Path: 135 out of 500Path: 129 out of 500
# Path: 136 out of 500
#
# Path: 131 out of 500
# Path: 135 out of 500Path: 138 out of 500Path: 127 out of 500
# Path: 137 out of 500
# Path: 136 out of 500
#
#
# Path: 137 out of 500
# Path: 130 out of 500Path: 136 out of 500Path: 139 out of 500Path: 138 out of 500
# Path: 138 out of 500Path: 137 out of 500
#
#
# Path: 132 out of 500
# Path: 128 out of 500
#
#
# Path: 131 out of 500
# Path: 140 out of 500Path: 137 out of 500Path: 138 out of 500
#
# Path: 133 out of 500
# Path: 139 out of 500
# Path: 139 out of 500Path: 129 out of 500
#
#
# Path: 138 out of 500Path: 132 out of 500Path: 140 out of 500Path: 139 out of 500Path: 140 out of 500Path: 134 out of 500Path: 141 out of 500
#
#
#
#
#
# Path: 130 out of 500
#
# Path: 140 out of 500
# Path: 135 out of 500Path: 141 out of 500Path: 142 out of 500Path: 139 out of 500
# Path: 131 out of 500
# Path: 133 out of 500
#
# Path: 141 out of 500
#
#
# Path: 136 out of 500Path: 141 out of 500
# Path: 140 out of 500Path: 142 out of 500
#
# Path: 134 out of 500Path: 132 out of 500Path: 143 out of 500
#
#
# Path: 142 out of 500
#
# Path: 137 out of 500Path: 133 out of 500Path: 143 out of 500
#
#
# Path: 141 out of 500Path: 135 out of 500
# Path: 143 out of 500
#
# Path: 142 out of 500
# Path: 138 out of 500Path: 144 out of 500
# Path: 142 out of 500
# Path: 136 out of 500Path: 144 out of 500
#
#
# Path: 144 out of 500
# Path: 145 out of 500
# Path: 143 out of 500Path: 134 out of 500
#
# Path: 137 out of 500Path: 143 out of 500Path: 139 out of 500Path: 145 out of 500
#
#
# Path: 145 out of 500
# Path: 146 out of 500
#
# Path: 135 out of 500Path: 138 out of 500Path: 144 out of 500
# Path: 146 out of 500
#
# Path: 146 out of 500Path: 144 out of 500
#
#
# Path: 147 out of 500Path: 140 out of 500
#
# Path: 136 out of 500Path: 145 out of 500
#
# Path: 139 out of 500Path: 147 out of 500Path: 141 out of 500Path: 147 out of 500
#
#
# Path: 148 out of 500
# Path: 145 out of 500
# Path: 137 out of 500
# Path: 146 out of 500
#
# Path: 146 out of 500Path: 148 out of 500Path: 138 out of 500Path: 140 out of 500Path: 142 out of 500
# Path: 148 out of 500
#
#
#
#
# Path: 149 out of 500
# Path: 139 out of 500Path: 149 out of 500Path: 147 out of 500
# Path: 143 out of 500
#
#
# Path: 147 out of 500Path: 149 out of 500
# Path: 150 out of 500
# Path: 150 out of 500
# Path: 141 out of 500
# Path: 140 out of 500
#
# Path: 144 out of 500Path: 150 out of 500
# Path: 148 out of 500
#
# Path: 148 out of 500
# Path: 151 out of 500Path: 141 out of 500Path: 142 out of 500Path: 145 out of 500
#
#
#
# Path: 151 out of 500
# Path: 151 out of 500Path: 149 out of 500Path: 146 out of 500Path: 149 out of 500
# Path: 152 out of 500
# Path: 143 out of 500
#
# Path: 142 out of 500Path: 152 out of 500
#
#
#
# Path: 147 out of 500
# Path: 150 out of 500Path: 143 out of 500Path: 150 out of 500Path: 152 out of 500
#
# Path: 153 out of 500
#
# Path: 153 out of 500Path: 144 out of 500
#
#
# Path: 148 out of 500Path: 144 out of 500
#
# Path: 153 out of 500
# Path: 151 out of 500
# Path: 151 out of 500Path: 145 out of 500Path: 145 out of 500Path: 154 out of 500Path: 149 out of 500
#
#
# Path: 154 out of 500
#
#
# Path: 154 out of 500Path: 152 out of 500
# Path: 146 out of 500Path: 155 out of 500
# Path: 152 out of 500Path: 155 out of 500
#
# Path: 146 out of 500
# Path: 150 out of 500
# Path: 155 out of 500
#
#
# Path: 156 out of 500Path: 153 out of 500Path: 153 out of 500
#
# Path: 147 out of 500
# Path: 151 out of 500
# Path: 156 out of 500
#
# Path: 147 out of 500Path: 157 out of 500
#
# Path: 156 out of 500Path: 154 out of 500Path: 148 out of 500
# Path: 154 out of 500
# Path: 152 out of 500
# Path: 158 out of 500
#
# Path: 157 out of 500
# Path: 148 out of 500
#
# Path: 157 out of 500Path: 149 out of 500
# Path: 159 out of 500
# Path: 153 out of 500Path: 158 out of 500Path: 155 out of 500
# Path: 155 out of 500
#
#
# Path: 149 out of 500
# Path: 158 out of 500
#
# Path: 150 out of 500Path: 154 out of 500
#
# Path: 159 out of 500Path: 156 out of 500Path: 150 out of 500
# Path: 159 out of 500
#
# Path: 160 out of 500
# Path: 156 out of 500Path: 151 out of 500
#
#
# Path: 157 out of 500Path: 155 out of 500Path: 160 out of 500Path: 160 out of 500Path: 157 out of 500
#
# Path: 151 out of 500
#
#
#
# Path: 152 out of 500Path: 161 out of 500
#
# Path: 158 out of 500Path: 152 out of 500
# Path: 156 out of 500Path: 158 out of 500
#
# Path: 161 out of 500
#
# Path: 159 out of 500Path: 161 out of 500Path: 162 out of 500
#
#
# Path: 153 out of 500Path: 153 out of 500Path: 157 out of 500
#
#
# Path: 159 out of 500Path: 160 out of 500
#
# Path: 162 out of 500Path: 163 out of 500
#
# Path: 154 out of 500Path: 162 out of 500Path: 154 out of 500
#
# Path: 160 out of 500
# Path: 158 out of 500
#
# Path: 161 out of 500Path: 164 out of 500Path: 163 out of 500
#
# Path: 161 out of 500
#
# Path: 163 out of 500Path: 155 out of 500Path: 155 out of 500
# Path: 159 out of 500Path: 165 out of 500
# Path: 164 out of 500
#
# Path: 162 out of 500
#
#
# Path: 162 out of 500Path: 164 out of 500Path: 160 out of 500
#
#
# Path: 156 out of 500Path: 166 out of 500Path: 163 out of 500
# Path: 165 out of 500
# Path: 165 out of 500
#
#
# Path: 156 out of 500Path: 164 out of 500
#
# Path: 161 out of 500Path: 163 out of 500
# Path: 166 out of 500Path: 157 out of 500Path: 166 out of 500
#
# Path: 167 out of 500
# Path: 157 out of 500Path: 165 out of 500
#
#
#
# Path: 162 out of 500Path: 167 out of 500
#
# Path: 158 out of 500Path: 164 out of 500
#
# Path: 168 out of 500Path: 167 out of 500
#
# Path: 166 out of 500Path: 163 out of 500
#
# Path: 158 out of 500Path: 168 out of 500
#
# Path: 165 out of 500Path: 168 out of 500
#
# Path: 169 out of 500Path: 159 out of 500
#
# Path: 164 out of 500
# Path: 169 out of 500Path: 159 out of 500Path: 167 out of 500
# Path: 169 out of 500
#
#
# Path: 160 out of 500Path: 166 out of 500
# Path: 165 out of 500Path: 170 out of 500
#
#
# Path: 160 out of 500Path: 168 out of 500Path: 170 out of 500
#
#
# Path: 167 out of 500
# Path: 161 out of 500
# Path: 171 out of 500Path: 170 out of 500
#
# Path: 166 out of 500Path: 169 out of 500Path: 171 out of 500
# Path: 161 out of 500
#
#
# Path: 162 out of 500
# Path: 168 out of 500Path: 172 out of 500
# Path: 171 out of 500Path: 167 out of 500
#
#
# Path: 170 out of 500Path: 162 out of 500Path: 163 out of 500
#
#
# Path: 172 out of 500
# Path: 172 out of 500Path: 173 out of 500Path: 169 out of 500
# Path: 168 out of 500
#
#
# Path: 164 out of 500Path: 173 out of 500
# Path: 163 out of 500
#
# Path: 170 out of 500Path: 171 out of 500Path: 173 out of 500Path: 174 out of 500Path: 169 out of 500
#
# Path: 165 out of 500Path: 174 out of 500
#
#
#
#
# Path: 164 out of 500
# Path: 172 out of 500Path: 170 out of 500
# Path: 171 out of 500Path: 174 out of 500Path: 175 out of 500
#
# Path: 175 out of 500Path: 166 out of 500
#
#
#
# Path: 165 out of 500
# Path: 172 out of 500Path: 175 out of 500Path: 176 out of 500
# Path: 173 out of 500Path: 176 out of 500
# Path: 167 out of 500Path: 171 out of 500Path: 166 out of 500
#
#
#
#
#
# Path: 173 out of 500
# Path: 176 out of 500
# Path: 177 out of 500Path: 177 out of 500Path: 172 out of 500Path: 168 out of 500Path: 174 out of 500
# Path: 177 out of 500Path: 174 out of 500
# Path: 167 out of 500
#
#
#
#
#
# Path: 178 out of 500
# Path: 173 out of 500Path: 175 out of 500
# Path: 175 out of 500
# Path: 178 out of 500Path: 178 out of 500
#
#
# Path: 168 out of 500Path: 179 out of 500
#
# Path: 176 out of 500Path: 169 out of 500
# Path: 176 out of 500
# Path: 179 out of 500
# Path: 169 out of 500
# Path: 174 out of 500Path: 179 out of 500
#
# Path: 180 out of 500
#
# Path: 177 out of 500
# Path: 177 out of 500Path: 175 out of 500
#
# Path: 180 out of 500Path: 180 out of 500Path: 170 out of 500
#
# Path: 170 out of 500
# Path: 181 out of 500
#
# Path: 178 out of 500
# Path: 176 out of 500Path: 178 out of 500Path: 181 out of 500Path: 182 out of 500
#
#
# Path: 181 out of 500
#
# Path: 171 out of 500Path: 171 out of 500
#
# Path: 179 out of 500Path: 179 out of 500
#
# Path: 182 out of 500Path: 177 out of 500Path: 183 out of 500Path: 182 out of 500
#
#
#
# Path: 180 out of 500Path: 172 out of 500Path: 183 out of 500Path: 180 out of 500
# Path: 172 out of 500
#
#
#
# Path: 178 out of 500Path: 184 out of 500Path: 184 out of 500
#
#
# Path: 183 out of 500
# Path: 173 out of 500Path: 173 out of 500
# Path: 181 out of 500Path: 185 out of 500
#
#
# Path: 179 out of 500Path: 185 out of 500Path: 184 out of 500Path: 174 out of 500Path: 181 out of 500
#
#
#
#
# Path: 186 out of 500Path: 174 out of 500
#
# Path: 182 out of 500Path: 182 out of 500
# Path: 180 out of 500
# Path: 185 out of 500
# Path: 186 out of 500Path: 175 out of 500
#
# Path: 183 out of 500
#
# Path: 175 out of 500Path: 187 out of 500
# Path: 181 out of 500
# Path: 183 out of 500
# Path: 176 out of 500
# Path: 186 out of 500
# Path: 187 out of 500
# Path: 176 out of 500Path: 184 out of 500Path: 188 out of 500
#
#
#
# Path: 184 out of 500
# Path: 177 out of 500Path: 182 out of 500Path: 185 out of 500
#
# Path: 177 out of 500
# Path: 187 out of 500
#
# Path: 189 out of 500Path: 188 out of 500
# Path: 178 out of 500Path: 185 out of 500Path: 186 out of 500Path: 183 out of 500
#
#
#
# Path: 188 out of 500
# Path: 178 out of 500Path: 189 out of 500Path: 184 out of 500
# Path: 190 out of 500
#
#
# Path: 179 out of 500Path: 187 out of 500Path: 186 out of 500
#
#
# Path: 189 out of 500Path: 179 out of 500Path: 185 out of 500
#
# Path: 190 out of 500
# Path: 180 out of 500
# Path: 187 out of 500Path: 180 out of 500
# Path: 188 out of 500Path: 190 out of 500
#
#
#
# Path: 191 out of 500Path: 191 out of 500Path: 186 out of 500
#
#
# Path: 191 out of 500Path: 188 out of 500Path: 189 out of 500Path: 181 out of 500
#
#
#
# Path: 181 out of 500Path: 192 out of 500Path: 192 out of 500
#
#
# Path: 189 out of 500Path: 192 out of 500
# Path: 187 out of 500Path: 182 out of 500Path: 190 out of 500
#
#
# Path: 193 out of 500
# Path: 182 out of 500Path: 193 out of 500
#
#
# Path: 193 out of 500
# Path: 183 out of 500Path: 190 out of 500Path: 191 out of 500Path: 188 out of 500
#
# Path: 183 out of 500
#
# Path: 194 out of 500
# Path: 194 out of 500Path: 194 out of 500
#
#
# Path: 191 out of 500
# Path: 184 out of 500Path: 184 out of 500Path: 192 out of 500Path: 195 out of 500
#
#
#
# Path: 189 out of 500
# Path: 195 out of 500Path: 196 out of 500Path: 193 out of 500Path: 192 out of 500Path: 195 out of 500
# Path: 185 out of 500
#
# Path: 185 out of 500
#
#
#
# Path: 197 out of 500Path: 190 out of 500
# Path: 193 out of 500
# Path: 194 out of 500
#
# Path: 186 out of 500Path: 196 out of 500
#
# Path: 186 out of 500Path: 196 out of 500Path: 195 out of 500Path: 198 out of 500Path: 191 out of 500
#
#
#
#
# Path: 187 out of 500
# Path: 197 out of 500Path: 197 out of 500Path: 196 out of 500
#
# Path: 194 out of 500
#
# Path: 187 out of 500Path: 192 out of 500Path: 199 out of 500
# Path: 198 out of 500
#
#
# Path: 188 out of 500Path: 198 out of 500
# Path: 195 out of 500
# Path: 197 out of 500
# Path: 188 out of 500
# Path: 193 out of 500
# Path: 196 out of 500Path: 200 out of 500
# Path: 199 out of 500
# Path: 189 out of 500
#
# Path: 189 out of 500Path: 199 out of 500Path: 198 out of 500
#
#
#
# Path: 201 out of 500Path: 194 out of 500Path: 197 out of 500Path: 200 out of 500
#
#
#
# Path: 199 out of 500Path: 190 out of 500Path: 190 out of 500
#
#
# Path: 198 out of 500Path: 200 out of 500
#
# Path: 201 out of 500Path: 200 out of 500
# Path: 195 out of 500Path: 201 out of 500Path: 191 out of 500Path: 199 out of 500
#
#
#
#
# Path: 202 out of 500Path: 191 out of 500
#
# Path: 196 out of 500
# Path: 192 out of 500Path: 200 out of 500Path: 202 out of 500Path: 202 out of 500
#
#
# Path: 201 out of 500
#
# Path: 203 out of 500Path: 192 out of 500
#
# Path: 197 out of 500Path: 201 out of 500
#
# Path: 193 out of 500Path: 203 out of 500Path: 202 out of 500
#
#
# Path: 193 out of 500Path: 204 out of 500Path: 202 out of 500
#
#
# Path: 203 out of 500Path: 203 out of 500Path: 198 out of 500
#
#
# Path: 194 out of 500Path: 205 out of 500
# Path: 203 out of 500
#
# Path: 204 out of 500Path: 204 out of 500Path: 194 out of 500
#
# Path: 204 out of 500Path: 204 out of 500Path: 199 out of 500
# Path: 195 out of 500
#
#
#
# Path: 205 out of 500Path: 195 out of 500
# Path: 206 out of 500
# Path: 205 out of 500
# Path: 196 out of 500
# Path: 205 out of 500
# Path: 200 out of 500Path: 205 out of 500
#
#
# Path: 196 out of 500Path: 207 out of 500
#
# Path: 206 out of 500Path: 197 out of 500Path: 206 out of 500
# Path: 197 out of 500Path: 208 out of 500Path: 206 out of 500Path: 206 out of 500
# Path: 201 out of 500
#
#
#
#
#
# Path: 207 out of 500Path: 207 out of 500Path: 202 out of 500Path: 198 out of 500
#
#
#
# Path: 207 out of 500Path: 198 out of 500
# Path: 209 out of 500
#
# Path: 208 out of 500
# Path: 207 out of 500Path: 208 out of 500
# Path: 199 out of 500
# Path: 199 out of 500
# Path: 210 out of 500Path: 203 out of 500
# Path: 208 out of 500
# Path: 209 out of 500
#
#
# Path: 200 out of 500Path: 209 out of 500Path: 208 out of 500
#
#
# Path: 200 out of 500
# Path: 204 out of 500Path: 211 out of 500
#
# Path: 209 out of 500Path: 209 out of 500Path: 210 out of 500
#
# Path: 210 out of 500Path: 201 out of 500
#
# Path: 201 out of 500
#
# Path: 212 out of 500Path: 210 out of 500Path: 205 out of 500Path: 210 out of 500
#
#
#
# Path: 202 out of 500Path: 211 out of 500
#
# Path: 202 out of 500Path: 211 out of 500Path: 213 out of 500Path: 206 out of 500
#
#
# Path: 211 out of 500
#
# Path: 203 out of 500Path: 211 out of 500Path: 207 out of 500Path: 212 out of 500Path: 203 out of 500
# Path: 212 out of 500
#
#
#
# Path: 214 out of 500
#
# Path: 212 out of 500
# Path: 204 out of 500
# Path: 213 out of 500Path: 208 out of 500Path: 212 out of 500Path: 213 out of 500
#
# Path: 213 out of 500
#
# Path: 205 out of 500Path: 215 out of 500
# Path: 204 out of 500Path: 209 out of 500
#
#
#
# Path: 214 out of 500
# Path: 214 out of 500Path: 214 out of 500Path: 206 out of 500
# Path: 205 out of 500
# Path: 213 out of 500
#
#
# Path: 210 out of 500Path: 216 out of 500
#
# Path: 215 out of 500Path: 215 out of 500
#
# Path: 206 out of 500Path: 207 out of 500
# Path: 217 out of 500Path: 215 out of 500
# Path: 214 out of 500Path: 211 out of 500
#
#
#
# Path: 216 out of 500Path: 207 out of 500
# Path: 208 out of 500
#
# Path: 218 out of 500Path: 212 out of 500Path: 216 out of 500
#
# Path: 215 out of 500
# Path: 216 out of 500
#
# Path: 217 out of 500
# Path: 209 out of 500Path: 219 out of 500Path: 213 out of 500
#
#
# Path: 217 out of 500Path: 217 out of 500
#
# Path: 216 out of 500Path: 208 out of 500
# Path: 210 out of 500Path: 218 out of 500Path: 214 out of 500
#
#
#
# Path: 218 out of 500Path: 218 out of 500
#
# Path: 220 out of 500Path: 217 out of 500
# Path: 219 out of 500Path: 215 out of 500
#
#
# Path: 211 out of 500
# Path: 209 out of 500Path: 221 out of 500
# Path: 218 out of 500
# Path: 220 out of 500
#
# Path: 219 out of 500
# Path: 212 out of 500Path: 219 out of 500Path: 216 out of 500
#
# Path: 221 out of 500
# Path: 210 out of 500Path: 222 out of 500
#
# Path: 219 out of 500Path: 220 out of 500Path: 217 out of 500
#
#
#
# Path: 213 out of 500Path: 220 out of 500Path: 222 out of 500Path: 220 out of 500Path: 221 out of 500Path: 211 out of 500
#
#
#
# Path: 218 out of 500Path: 223 out of 500
#
#
#
# Path: 223 out of 500Path: 221 out of 500Path: 221 out of 500Path: 219 out of 500
# Path: 214 out of 500
# Path: 212 out of 500
#
# Path: 224 out of 500
#
#
# Path: 222 out of 500
# Path: 224 out of 500Path: 220 out of 500
#
# Path: 222 out of 500Path: 215 out of 500Path: 223 out of 500
# Path: 225 out of 500Path: 222 out of 500
#
#
#
# Path: 213 out of 500
# Path: 216 out of 500Path: 221 out of 500Path: 225 out of 500Path: 224 out of 500Path: 223 out of 500
# Path: 223 out of 500
#
#
# Path: 214 out of 500
# Path: 226 out of 500
#
#
# Path: 222 out of 500
# Path: 217 out of 500Path: 226 out of 500
# Path: 227 out of 500
#
# Path: 224 out of 500Path: 224 out of 500Path: 223 out of 500
#
#
# Path: 215 out of 500Path: 218 out of 500Path: 228 out of 500
# Path: 225 out of 500
#
#
# Path: 225 out of 500Path: 227 out of 500Path: 225 out of 500
#
# Path: 224 out of 500
# Path: 229 out of 500
# Path: 219 out of 500
#
# Path: 216 out of 500Path: 228 out of 500Path: 226 out of 500
#
# Path: 226 out of 500
# Path: 225 out of 500
# Path: 230 out of 500
# Path: 226 out of 500
# Path: 229 out of 500Path: 220 out of 500
# Path: 227 out of 500
# Path: 217 out of 500
#
#
# Path: 226 out of 500Path: 227 out of 500
# Path: 221 out of 500
#
# Path: 231 out of 500Path: 228 out of 500Path: 228 out of 500Path: 218 out of 500Path: 230 out of 500
#
#
#
#
# Path: 227 out of 500Path: 222 out of 500
#
# Path: 229 out of 500Path: 227 out of 500Path: 232 out of 500
# Path: 219 out of 500Path: 231 out of 500Path: 229 out of 500
#
#
#
# Path: 228 out of 500
# Path: 223 out of 500
#
# Path: 228 out of 500Path: 233 out of 500
#
# Path: 229 out of 500Path: 230 out of 500Path: 220 out of 500Path: 230 out of 500
#
#
# Path: 229 out of 500Path: 224 out of 500
# Path: 232 out of 500
# Path: 230 out of 500
#
#
# Path: 234 out of 500Path: 231 out of 500Path: 221 out of 500
#
#
# Path: 231 out of 500
# Path: 230 out of 500Path: 231 out of 500Path: 225 out of 500
#
# Path: 235 out of 500
#
# Path: 233 out of 500Path: 232 out of 500Path: 232 out of 500Path: 222 out of 500
#
#
#
# Path: 231 out of 500Path: 232 out of 500Path: 236 out of 500
#
#
# Path: 233 out of 500Path: 226 out of 500Path: 234 out of 500
#
#
# Path: 223 out of 500Path: 233 out of 500
#
# Path: 237 out of 500
# Path: 233 out of 500Path: 232 out of 500
# Path: 234 out of 500Path: 227 out of 500
# Path: 235 out of 500Path: 224 out of 500Path: 238 out of 500
#
#
# Path: 234 out of 500
#
# Path: 234 out of 500
#
# Path: 235 out of 500Path: 228 out of 500Path: 233 out of 500
# Path: 239 out of 500
#
# Path: 225 out of 500Path: 236 out of 500
# Path: 235 out of 500
#
#
# Path: 235 out of 500Path: 234 out of 500
#
# Path: 236 out of 500Path: 226 out of 500
#
# Path: 229 out of 500Path: 240 out of 500Path: 237 out of 500
# Path: 236 out of 500
# Path: 235 out of 500
#
#
# Path: 241 out of 500Path: 236 out of 500Path: 227 out of 500
#
# Path: 230 out of 500
#
# Path: 237 out of 500Path: 237 out of 500Path: 236 out of 500
# Path: 238 out of 500
#
# Path: 242 out of 500Path: 237 out of 500
#
#
# Path: 243 out of 500Path: 231 out of 500Path: 238 out of 500
# Path: 238 out of 500
# Path: 228 out of 500
#
#
# Path: 237 out of 500Path: 239 out of 500Path: 238 out of 500
#
#
# Path: 232 out of 500
# Path: 239 out of 500Path: 240 out of 500Path: 244 out of 500
# Path: 229 out of 500Path: 239 out of 500
#
#
# Path: 238 out of 500Path: 239 out of 500
# Path: 240 out of 500
# Path: 233 out of 500
#
#
# Path: 245 out of 500Path: 230 out of 500
#
# Path: 241 out of 500Path: 240 out of 500Path: 239 out of 500Path: 241 out of 500
#
#
# Path: 234 out of 500Path: 240 out of 500
#
#
# Path: 246 out of 500Path: 231 out of 500
# Path: 242 out of 500Path: 241 out of 500Path: 242 out of 500Path: 235 out of 500
#
#
#
# Path: 241 out of 500
# Path: 240 out of 500
#
# Path: 247 out of 500
# Path: 243 out of 500Path: 242 out of 500Path: 243 out of 500
# Path: 242 out of 500Path: 236 out of 500
#
#
#
# Path: 241 out of 500Path: 244 out of 500Path: 243 out of 500Path: 248 out of 500
#
# Path: 244 out of 500Path: 232 out of 500Path: 243 out of 500
#
#
#
# Path: 237 out of 500
#
# Path: 244 out of 500Path: 245 out of 500
#
# Path: 233 out of 500Path: 245 out of 500Path: 238 out of 500Path: 244 out of 500
#
# Path: 242 out of 500
#
# Path: 245 out of 500
#
# Path: 246 out of 500Path: 246 out of 500Path: 249 out of 500
# Path: 243 out of 500Path: 239 out of 500
# Path: 246 out of 500Path: 245 out of 500
#
#
#
# Path: 234 out of 500
# Path: 244 out of 500Path: 250 out of 500Path: 247 out of 500Path: 247 out of 500
#
# Path: 247 out of 500
# Path: 235 out of 500
#
#
# Path: 246 out of 500Path: 240 out of 500
#
# Path: 245 out of 500Path: 248 out of 500
#
# Path: 248 out of 500Path: 251 out of 500Path: 248 out of 500Path: 236 out of 500
#
#
#
# Path: 246 out of 500Path: 252 out of 500Path: 241 out of 500
# Path: 237 out of 500Path: 249 out of 500Path: 249 out of 500Path: 247 out of 500Path: 249 out of 500
#
#
#
#
#
#
# Path: 250 out of 500Path: 250 out of 500Path: 253 out of 500
#
# Path: 248 out of 500Path: 242 out of 500
# Path: 238 out of 500
#
#
# Path: 250 out of 500
# Path: 251 out of 500Path: 251 out of 500Path: 254 out of 500
#
# Path: 247 out of 500
#
# Path: 243 out of 500
# Path: 251 out of 500Path: 249 out of 500Path: 239 out of 500
# Path: 252 out of 500
# Path: 252 out of 500
#
#
# Path: 255 out of 500
# Path: 250 out of 500Path: 244 out of 500Path: 240 out of 500Path: 248 out of 500
# Path: 252 out of 500Path: 253 out of 500
#
#
#
#
# Path: 256 out of 500Path: 253 out of 500Path: 249 out of 500
# Path: 241 out of 500Path: 254 out of 500
#
#
# Path: 253 out of 500Path: 245 out of 500
#
#
# Path: 242 out of 500Path: 251 out of 500Path: 254 out of 500Path: 257 out of 500
# Path: 246 out of 500
#
# Path: 250 out of 500
#
#
# Path: 254 out of 500
# Path: 255 out of 500Path: 252 out of 500Path: 243 out of 500
#
#
# Path: 255 out of 500Path: 258 out of 500Path: 247 out of 500
#
#
# Path: 251 out of 500
# Path: 255 out of 500Path: 253 out of 500
# Path: 256 out of 500
#
# Path: 244 out of 500Path: 259 out of 500Path: 256 out of 500
#
# Path: 252 out of 500
# Path: 248 out of 500
#
# Path: 256 out of 500Path: 254 out of 500
# Path: 257 out of 500Path: 260 out of 500
# Path: 253 out of 500
# Path: 249 out of 500Path: 245 out of 500Path: 257 out of 500
#
#
#
#
# Path: 258 out of 500Path: 257 out of 500
#
# Path: 261 out of 500Path: 258 out of 500
# Path: 250 out of 500
# Path: 254 out of 500Path: 246 out of 500Path: 255 out of 500
#
#
#
# Path: 259 out of 500
# Path: 258 out of 500Path: 256 out of 500Path: 262 out of 500
#
#
# Path: 247 out of 500Path: 251 out of 500
#
# Path: 259 out of 500Path: 255 out of 500Path: 259 out of 500
# Path: 260 out of 500
# Path: 263 out of 500
#
#
# Path: 257 out of 500Path: 248 out of 500
# Path: 252 out of 500
#
# Path: 264 out of 500Path: 256 out of 500
# Path: 260 out of 500
# Path: 261 out of 500
# Path: 258 out of 500
# Path: 260 out of 500
# Path: 249 out of 500
#
# Path: 262 out of 500Path: 253 out of 500Path: 257 out of 500Path: 261 out of 500
#
# Path: 259 out of 500
#
#
# Path: 265 out of 500
# Path: 250 out of 500Path: 261 out of 500Path: 262 out of 500Path: 263 out of 500
#
#
#
# Path: 258 out of 500Path: 266 out of 500Path: 254 out of 500
#
#
# Path: 264 out of 500Path: 260 out of 500
# Path: 263 out of 500Path: 251 out of 500Path: 259 out of 500
#
#
# Path: 262 out of 500Path: 267 out of 500
# Path: 265 out of 500
#
#
# Path: 255 out of 500Path: 264 out of 500Path: 252 out of 500
#
# Path: 260 out of 500
#
# Path: 268 out of 500Path: 266 out of 500
# Path: 261 out of 500
# Path: 265 out of 500
# Path: 256 out of 500Path: 263 out of 500
#
#
# Path: 261 out of 500Path: 269 out of 500Path: 266 out of 500
# Path: 262 out of 500
# Path: 253 out of 500
# Path: 267 out of 500Path: 257 out of 500
#
#
#
# Path: 264 out of 500
# Path: 270 out of 500Path: 267 out of 500
#
# Path: 262 out of 500Path: 254 out of 500Path: 263 out of 500Path: 258 out of 500Path: 268 out of 500
#
# Path: 265 out of 500
#
# Path: 271 out of 500
#
#
# Path: 268 out of 500
# Path: 263 out of 500
# Path: 269 out of 500Path: 264 out of 500
# Path: 272 out of 500Path: 259 out of 500
# Path: 255 out of 500Path: 270 out of 500
# Path: 269 out of 500
# Path: 264 out of 500
#
#
# Path: 266 out of 500
#
# Path: 271 out of 500Path: 273 out of 500
#
# Path: 265 out of 500Path: 270 out of 500Path: 260 out of 500
#
#
# Path: 256 out of 500Path: 267 out of 500Path: 274 out of 500
# Path: 265 out of 500
#
#
# Path: 272 out of 500
# Path: 271 out of 500Path: 257 out of 500Path: 261 out of 500Path: 266 out of 500
#
#
#
# Path: 266 out of 500Path: 268 out of 500
#
# Path: 273 out of 500Path: 262 out of 500
#
# Path: 272 out of 500Path: 274 out of 500Path: 267 out of 500Path: 267 out of 500
# Path: 275 out of 500
# Path: 258 out of 500
#
#
# Path: 263 out of 500
# Path: 269 out of 500
#
# Path: 273 out of 500
# Path: 268 out of 500Path: 270 out of 500
#
# Path: 276 out of 500Path: 264 out of 500Path: 259 out of 500Path: 268 out of 500
#
#
#
# Path: 274 out of 500
# Path: 265 out of 500Path: 271 out of 500Path: 269 out of 500
#
# Path: 269 out of 500
# Path: 275 out of 500Path: 277 out of 500
#
# Path: 275 out of 500Path: 260 out of 500
#
#
# Path: 266 out of 500Path: 272 out of 500Path: 270 out of 500
#
# Path: 278 out of 500Path: 270 out of 500
#
# Path: 276 out of 500
#
# Path: 276 out of 500Path: 261 out of 500
# Path: 271 out of 500Path: 271 out of 500Path: 267 out of 500Path: 273 out of 500
#
#
#
# Path: 277 out of 500Path: 279 out of 500
#
#
# Path: 262 out of 500Path: 272 out of 500
#
# Path: 268 out of 500Path: 278 out of 500Path: 274 out of 500
# Path: 280 out of 500Path: 272 out of 500
#
#
#
# Path: 277 out of 500
# Path: 263 out of 500Path: 275 out of 500
# Path: 273 out of 500Path: 273 out of 500Path: 269 out of 500Path: 281 out of 500
#
#
#
# Path: 278 out of 500
# Path: 279 out of 500
#
# Path: 270 out of 500
# Path: 282 out of 500Path: 264 out of 500Path: 274 out of 500Path: 274 out of 500
# Path: 276 out of 500
# Path: 279 out of 500
#
#
# Path: 280 out of 500
#
# Path: 283 out of 500Path: 271 out of 500Path: 265 out of 500
#
# Path: 281 out of 500
# Path: 277 out of 500Path: 275 out of 500
# Path: 280 out of 500
#
#
# Path: 275 out of 500Path: 284 out of 500
#
# Path: 276 out of 500Path: 272 out of 500
#
# Path: 281 out of 500
# Path: 278 out of 500
# Path: 273 out of 500Path: 276 out of 500Path: 277 out of 500
#
#
# Path: 282 out of 500
# Path: 266 out of 500Path: 282 out of 500Path: 279 out of 500
#
# Path: 277 out of 500
#
# Path: 278 out of 500Path: 285 out of 500Path: 274 out of 500
#
#
# Path: 280 out of 500Path: 283 out of 500
#
# Path: 283 out of 500Path: 267 out of 500
#
# Path: 278 out of 500Path: 279 out of 500Path: 275 out of 500
#
#
# Path: 286 out of 500
# Path: 284 out of 500Path: 284 out of 500
# Path: 268 out of 500Path: 280 out of 500
# Path: 281 out of 500
# Path: 279 out of 500
#
# Path: 276 out of 500
#
# Path: 285 out of 500Path: 287 out of 500Path: 285 out of 500
#
#
# Path: 269 out of 500Path: 281 out of 500Path: 282 out of 500
#
#
# Path: 277 out of 500Path: 280 out of 500
# Path: 288 out of 500
# Path: 286 out of 500Path: 286 out of 500
# Path: 270 out of 500
# Path: 283 out of 500
#
#
# Path: 278 out of 500Path: 282 out of 500Path: 271 out of 500
# Path: 281 out of 500Path: 287 out of 500
#
#
#
# Path: 284 out of 500
# Path: 289 out of 500Path: 287 out of 500Path: 279 out of 500
#
# Path: 282 out of 500Path: 283 out of 500
#
#
# Path: 285 out of 500
# Path: 288 out of 500Path: 272 out of 500Path: 280 out of 500Path: 290 out of 500
#
#
#
# Path: 286 out of 500Path: 283 out of 500Path: 288 out of 500
#
#
# Path: 284 out of 500Path: 289 out of 500
#
# Path: 273 out of 500Path: 281 out of 500
#
# ...
#
# Path: 194 out of 500
# Path: 048 out of 500
# Path: 195 out of 500
# Path: 049 out of 500
# Path: 050 out of 500
# Path: 196 out of 500
# Path: 051 out of 500
# Path: 197 out of 500
# Path: 052 out of 500
# Path: 198 out of 500Path: 053 out of 500
#
# Path: 054 out of 500Path: 199 out of 500
#
# Path: 055 out of 500
# Path: 200 out of 500
# Path: 056 out of 500
# Path: 201 out of 500
# Path: 057 out of 500
# Path: 202 out of 500
# Path: 058 out of 500
# Path: 203 out of 500Path: 059 out of 500
#
# Path: 060 out of 500
# Path: 204 out of 500Path: 061 out of 500
#
# Path: 062 out of 500
# Path: 205 out of 500
# Path: 063 out of 500
# Path: 206 out of 500
# Path: 064 out of 500
# Path: 207 out of 500
# Path: 065 out of 500
# Path: 208 out of 500
# Path: 066 out of 500
# Path: 067 out of 500Path: 209 out of 500
#
# Path: 068 out of 500
# Path: 210 out of 500
# Path: 069 out of 500Path: 211 out of 500
#
# Path: 070 out of 500
# Path: 212 out of 500
# Path: 071 out of 500
# Path: 213 out of 500
# Path: 072 out of 500
# Path: 073 out of 500Path: 214 out of 500
#
# Path: 074 out of 500
# Path: 215 out of 500
# Path: 075 out of 500
# Path: 216 out of 500Path: 076 out of 500
#
# Path: 077 out of 500
# Path: 217 out of 500
# Path: 078 out of 500
# Path: 218 out of 500
# Path: 079 out of 500
# Path: 219 out of 500
# Path: 080 out of 500
# Path: 220 out of 500
# Path: 081 out of 500
# Path: 082 out of 500
# Path: 221 out of 500Path: 083 out of 500
#
# Path: 084 out of 500
# Path: 222 out of 500
# Path: 085 out of 500
# Path: 086 out of 500
# Path: 223 out of 500
# Path: 224 out of 500
# Path: 087 out of 500
# Path: 225 out of 500
# Path: 088 out of 500
# Path: 226 out of 500Path: 089 out of 500
#
# Path: 227 out of 500
# Path: 090 out of 500
# Path: 228 out of 500
# Path: 091 out of 500
# Path: 229 out of 500
# Path: 092 out of 500
# Path: 230 out of 500Path: 093 out of 500
#
# Path: 094 out of 500
# Path: 231 out of 500
# Path: 095 out of 500
# Path: 232 out of 500Path: 096 out of 500
#
# Path: 097 out of 500
# Path: 233 out of 500
# Path: 098 out of 500
# Path: 234 out of 500
# Path: 099 out of 500
# Path: 235 out of 500
# Path: 100 out of 500
# Path: 236 out of 500
# Path: 101 out of 500Path: 237 out of 500
#
# Path: 238 out of 500
# Path: 102 out of 500Path: 239 out of 500
#
# Path: 103 out of 500
# Path: 240 out of 500
# Path: 104 out of 500
# Path: 241 out of 500
# Path: 105 out of 500
# Path: 242 out of 500
# Path: 106 out of 500
# Path: 107 out of 500
# Path: 243 out of 500
# Path: 108 out of 500
# Path: 244 out of 500
# Path: 109 out of 500
# Path: 245 out of 500Path: 110 out of 500
#
# Path: 111 out of 500Path: 246 out of 500
#
# Path: 247 out of 500Path: 112 out of 500
#
# Path: 248 out of 500
# Path: 113 out of 500
# Path: 114 out of 500
# Path: 249 out of 500
# Path: 115 out of 500
# Path: 250 out of 500
# Path: 116 out of 500
# Path: 251 out of 500
# Path: 117 out of 500
# Path: 252 out of 500
# Path: 118 out of 500
# Path: 253 out of 500
# Path: 119 out of 500
# Path: 254 out of 500
# Path: 120 out of 500
# Path: 255 out of 500
# Path: 121 out of 500
# Path: 256 out of 500
# Path: 122 out of 500
# Path: 257 out of 500
# Path: 123 out of 500
# Path: 258 out of 500
# Path: 124 out of 500
# Path: 259 out of 500
# Path: 125 out of 500
# Path: 260 out of 500
# Path: 126 out of 500
# Path: 261 out of 500
# Path: 127 out of 500
# Path: 128 out of 500
# Path: 262 out of 500
# Path: 129 out of 500
# Path: 263 out of 500
# Path: 130 out of 500
# Path: 264 out of 500
# Path: 131 out of 500Path: 265 out of 500
#
# Path: 266 out of 500Path: 132 out of 500
#
# Path: 133 out of 500Path: 267 out of 500
#
# Path: 268 out of 500Path: 134 out of 500
#
# Path: 135 out of 500
# Path: 269 out of 500
# Path: 136 out of 500
# Path: 137 out of 500Path: 270 out of 500
#
# Path: 138 out of 500
# Path: 271 out of 500
# Path: 139 out of 500Path: 272 out of 500
#
# Path: 140 out of 500
# Path: 273 out of 500
# Path: 141 out of 500
# Path: 274 out of 500
# Path: 142 out of 500
# Path: 275 out of 500
# Path: 143 out of 500
# Path: 276 out of 500
# Path: 144 out of 500
# Path: 277 out of 500Path: 145 out of 500
#
# Path: 278 out of 500
# Path: 146 out of 500
# Path: 279 out of 500
# Path: 147 out of 500Path: 280 out of 500
#
# Path: 281 out of 500
# Path: 148 out of 500
# Path: 149 out of 500
# Path: 282 out of 500
# Path: 150 out of 500
# Path: 283 out of 500
# Path: 151 out of 500
# Path: 152 out of 500
# Path: 284 out of 500
# Path: 153 out of 500
# Path: 285 out of 500
# Path: 154 out of 500
# Path: 155 out of 500
# Path: 286 out of 500
# Path: 156 out of 500
# Path: 287 out of 500
# Path: 157 out of 500
# Path: 158 out of 500
# Path: 288 out of 500
# Path: 159 out of 500
# Path: 160 out of 500Path: 289 out of 500
#
# Path: 161 out of 500
# Path: 290 out of 500
# Path: 162 out of 500
# Path: 163 out of 500Path: 291 out of 500
#
# Path: 164 out of 500Path: 292 out of 500
#
# Path: 293 out of 500
# Path: 165 out of 500
# Path: 294 out of 500
# Path: 166 out of 500
# Path: 295 out of 500
# Path: 167 out of 500
# Path: 296 out of 500
# Path: 168 out of 500
# Path: 297 out of 500Path: 169 out of 500
#
# Path: 298 out of 500
# Path: 170 out of 500
# Path: 299 out of 500Path: 171 out of 500
#
# Path: 172 out of 500
# Path: 300 out of 500
# Path: 173 out of 500
# Path: 174 out of 500
# Path: 301 out of 500
# Path: 175 out of 500
# Path: 302 out of 500
# Path: 176 out of 500
# Path: 303 out of 500Path: 177 out of 500
#
# Path: 178 out of 500Path: 304 out of 500
#
# Path: 179 out of 500
# Path: 305 out of 500
# Path: 180 out of 500
# Path: 306 out of 500
# Path: 181 out of 500
# Path: 182 out of 500
# Path: 183 out of 500
# Path: 307 out of 500
# Path: 184 out of 500
# Path: 308 out of 500
# Path: 185 out of 500
# Path: 186 out of 500
# Path: 309 out of 500
# Path: 187 out of 500
# Path: 310 out of 500
# Path: 188 out of 500
# Path: 311 out of 500Path: 189 out of 500
#
# Path: 190 out of 500
# Path: 312 out of 500
# Path: 191 out of 500
# Path: 313 out of 500
# Path: 192 out of 500
# Path: 314 out of 500
# Path: 193 out of 500
# Path: 194 out of 500
# Path: 315 out of 500
# Path: 195 out of 500
# Path: 316 out of 500
# Path: 196 out of 500
# Path: 197 out of 500Path: 317 out of 500
#
# Path: 198 out of 500
# Path: 318 out of 500
# Path: 199 out of 500
# Path: 319 out of 500
# Path: 200 out of 500
# Path: 320 out of 500Path: 201 out of 500
#
# Path: 202 out of 500
# Path: 321 out of 500
# Path: 203 out of 500
# Path: 204 out of 500
# Path: 322 out of 500
# Path: 205 out of 500
# Path: 206 out of 500Path: 323 out of 500
#
# Path: 207 out of 500
# Path: 324 out of 500
# Path: 208 out of 500
# Path: 209 out of 500
# Path: 325 out of 500
# Path: 210 out of 500
# Path: 211 out of 500
# Path: 326 out of 500
# Path: 212 out of 500
# Path: 327 out of 500Path: 213 out of 500
#
# Path: 214 out of 500
# Path: 328 out of 500
# Path: 215 out of 500
# Path: 329 out of 500
# Path: 216 out of 500
# Path: 217 out of 500
# Path: 330 out of 500
# Path: 218 out of 500
# Path: 331 out of 500
# Path: 219 out of 500
# Path: 220 out of 500Path: 332 out of 500
#
# Path: 221 out of 500
# Path: 333 out of 500
# Path: 222 out of 500
# Path: 334 out of 500
# Path: 223 out of 500
# Path: 335 out of 500
# Path: 224 out of 500
# Path: 336 out of 500
# Path: 337 out of 500Path: 225 out of 500
#
# Path: 338 out of 500
# Path: 226 out of 500
# Path: 227 out of 500
# Path: 339 out of 500
# Path: 228 out of 500
# Path: 340 out of 500Path: 229 out of 500
#
# Path: 341 out of 500
# Path: 230 out of 500
# Path: 231 out of 500
# Path: 342 out of 500
# Path: 232 out of 500
# Path: 343 out of 500
# Path: 233 out of 500
# Path: 234 out of 500
# Path: 344 out of 500
# Path: 345 out of 500
# Path: 235 out of 500
# Path: 346 out of 500
# Path: 236 out of 500
# Path: 347 out of 500
# Path: 237 out of 500
# Path: 348 out of 500
# Path: 238 out of 500
# Path: 239 out of 500
# Path: 349 out of 500
# Path: 240 out of 500
# Path: 350 out of 500
# Path: 241 out of 500
# Path: 351 out of 500
# Path: 242 out of 500
# Path: 352 out of 500
# Path: 243 out of 500
# Path: 353 out of 500
# Path: 244 out of 500
# Path: 354 out of 500
# Path: 245 out of 500
# Path: 355 out of 500
# Path: 356 out of 500
# Path: 246 out of 500
# Path: 357 out of 500
# Path: 247 out of 500
# Path: 358 out of 500
# Path: 248 out of 500
# Path: 359 out of 500
# Path: 249 out of 500
# Path: 360 out of 500
# Path: 250 out of 500
# Path: 361 out of 500
# Path: 251 out of 500
# Path: 362 out of 500
# Path: 252 out of 500
# Path: 363 out of 500
# Path: 253 out of 500
# Path: 364 out of 500
# Path: 254 out of 500
# Path: 255 out of 500
# Path: 365 out of 500
# Path: 256 out of 500
# Path: 366 out of 500
# Path: 257 out of 500
# Path: 367 out of 500
# Path: 258 out of 500
# Path: 368 out of 500
# Path: 259 out of 500
# Path: 260 out of 500
# Path: 369 out of 500
# Path: 261 out of 500
# Path: 370 out of 500
# Path: 262 out of 500
# Path: 371 out of 500
# Path: 263 out of 500
# Path: 372 out of 500Path: 264 out of 500
#
# Path: 373 out of 500
# Path: 265 out of 500
# Path: 374 out of 500Path: 266 out of 500
#
# Path: 267 out of 500
# Path: 375 out of 500
# Path: 268 out of 500
# Path: 376 out of 500
# Path: 269 out of 500
# Path: 377 out of 500
# Path: 270 out of 500
# Path: 271 out of 500
# Path: 378 out of 500
# Path: 272 out of 500
# Path: 273 out of 500
# Path: 379 out of 500
# Path: 274 out of 500
# Path: 380 out of 500
# Path: 275 out of 500
# Path: 381 out of 500
# Path: 276 out of 500
# Path: 382 out of 500Path: 277 out of 500
#
# Path: 278 out of 500Path: 383 out of 500
#
# Path: 279 out of 500
# Path: 384 out of 500
# Path: 280 out of 500
# Path: 385 out of 500
# Path: 281 out of 500
# Path: 386 out of 500
# Path: 282 out of 500
# Path: 387 out of 500
# Path: 283 out of 500
# Path: 388 out of 500
# Path: 284 out of 500
# Path: 389 out of 500
# Path: 285 out of 500
# Path: 390 out of 500
# Path: 286 out of 500
# Path: 391 out of 500
# Path: 392 out of 500Path: 287 out of 500
#
# Path: 393 out of 500
# Path: 288 out of 500
# Path: 394 out of 500
# Path: 395 out of 500
# Path: 289 out of 500
# Path: 396 out of 500
# Path: 290 out of 500
# Path: 397 out of 500
# Path: 291 out of 500
# Path: 398 out of 500
# Path: 292 out of 500
# Path: 399 out of 500
# Path: 400 out of 500Path: 293 out of 500
#
# Path: 294 out of 500Path: 401 out of 500
#
# Path: 402 out of 500
# Path: 295 out of 500
# Path: 403 out of 500
# Path: 296 out of 500
# Path: 404 out of 500
# Path: 297 out of 500
# Path: 405 out of 500
# Path: 298 out of 500
# Path: 406 out of 500
# Path: 299 out of 500
# Path: 407 out of 500
# Path: 300 out of 500
# Path: 408 out of 500
# Path: 301 out of 500
# Path: 409 out of 500
# Path: 302 out of 500
# Path: 410 out of 500
# Path: 411 out of 500
# Path: 303 out of 500
# Path: 412 out of 500
# Path: 304 out of 500
# Path: 413 out of 500
# Path: 305 out of 500Path: 414 out of 500
#
# Path: 306 out of 500
# Path: 415 out of 500
# Path: 307 out of 500Path: 416 out of 500
#
# Path: 308 out of 500
# Path: 417 out of 500
# Path: 309 out of 500
# Path: 418 out of 500
# Path: 310 out of 500
# Path: 419 out of 500
# Path: 311 out of 500
# Path: 420 out of 500
# Path: 312 out of 500
# Path: 421 out of 500
# Path: 313 out of 500
# Path: 422 out of 500
# Path: 314 out of 500
# Path: 423 out of 500
# Path: 315 out of 500
# Path: 424 out of 500
# Path: 425 out of 500
# Path: 316 out of 500
# Path: 426 out of 500
# Path: 317 out of 500
# Path: 427 out of 500
# Path: 318 out of 500
# Path: 428 out of 500
# Path: 429 out of 500
# Path: 319 out of 500
# Path: 430 out of 500
# Path: 320 out of 500
# Path: 431 out of 500
# Path: 432 out of 500Path: 321 out of 500
#
# Path: 433 out of 500
# Path: 322 out of 500
# Path: 434 out of 500
# Path: 323 out of 500
# Path: 435 out of 500Path: 324 out of 500
#
# Path: 436 out of 500
# Path: 325 out of 500
# Path: 437 out of 500
# Path: 326 out of 500
# Path: 438 out of 500
# Path: 327 out of 500
# Path: 439 out of 500
# Path: 328 out of 500
# Path: 440 out of 500
# Path: 329 out of 500
# Path: 441 out of 500
# Path: 330 out of 500
# Path: 442 out of 500
# Path: 443 out of 500
# Path: 331 out of 500
# Path: 444 out of 500
# Path: 332 out of 500
# Path: 445 out of 500
# Path: 333 out of 500
# Path: 446 out of 500
# Path: 334 out of 500
# Path: 447 out of 500
# Path: 335 out of 500
# Path: 448 out of 500
# Path: 336 out of 500
# Path: 449 out of 500
# Path: 337 out of 500Path: 450 out of 500
#
# Path: 451 out of 500
# Path: 338 out of 500
# Path: 452 out of 500
# Path: 339 out of 500
# Path: 453 out of 500
# Path: 340 out of 500
# Path: 454 out of 500
# Path: 341 out of 500
# Path: 455 out of 500
# Path: 342 out of 500
# Path: 456 out of 500
# Path: 343 out of 500
# Path: 344 out of 500Path: 457 out of 500
#
# Path: 458 out of 500
# Path: 345 out of 500
# Path: 459 out of 500
# Path: 346 out of 500
# Path: 460 out of 500
# Path: 347 out of 500
# Path: 461 out of 500
# Path: 348 out of 500
# Path: 462 out of 500
# Path: 349 out of 500
# Path: 463 out of 500
# Path: 350 out of 500
# Path: 464 out of 500
# Path: 351 out of 500
# Path: 465 out of 500
# Path: 352 out of 500
# Path: 466 out of 500
# Path: 353 out of 500
# Path: 467 out of 500
# Path: 354 out of 500
# Path: 468 out of 500
# Path: 469 out of 500
# Path: 355 out of 500
# Path: 470 out of 500
# Path: 356 out of 500
# Path: 471 out of 500
# Path: 357 out of 500
# Path: 472 out of 500Path: 358 out of 500
#
# Path: 473 out of 500
# Path: 359 out of 500
# Path: 474 out of 500
# Path: 475 out of 500
# Path: 360 out of 500
# Path: 476 out of 500Path: 361 out of 500
#
# Path: 477 out of 500
# Path: 362 out of 500
# Path: 478 out of 500
# Path: 363 out of 500
# Path: 479 out of 500
# Path: 364 out of 500Path: 480 out of 500
#
# Path: 365 out of 500
# Path: 481 out of 500
# Path: 366 out of 500
# Path: 482 out of 500
# Path: 367 out of 500
# Path: 483 out of 500
# Path: 368 out of 500
# Path: 484 out of 500Path: 369 out of 500
#
# Path: 370 out of 500
# Path: 485 out of 500
# Path: 371 out of 500
# Path: 486 out of 500
# Path: 372 out of 500
# Path: 487 out of 500
# Path: 373 out of 500
# Path: 488 out of 500
# Path: 374 out of 500
# Path: 489 out of 500
# Path: 375 out of 500
# Path: 490 out of 500
# Path: 376 out of 500
# Path: 491 out of 500
# Path: 377 out of 500
# Path: 492 out of 500
# Path: 493 out of 500
# Path: 378 out of 500
# Path: 494 out of 500
# Path: 379 out of 500
# Path: 495 out of 500
# Path: 380 out of 500
# Path: 496 out of 500
# Path: 381 out of 500
# Path: 497 out of 500
# Path: 382 out of 500
# Path: 498 out of 500
# Path: 499 out of 500Path: 383 out of 500
#
# Path: 384 out of 500
# Path: 385 out of 500
# Path: 386 out of 500
# Path: 387 out of 500
# Path: 388 out of 500
# Path: 389 out of 500
# Path: 390 out of 500
# Path: 391 out of 500
# Path: 392 out of 500
# Path: 393 out of 500
# Path: 394 out of 500
# Path: 395 out of 500
# Path: 396 out of 500
# Path: 397 out of 500
# Path: 398 out of 500
# Path: 399 out of 500
# Path: 400 out of 500
# Path: 401 out of 500
# Path: 402 out of 500
# Path: 403 out of 500
# Path: 404 out of 500
# Path: 405 out of 500
# Path: 406 out of 500
# Path: 407 out of 500
# Path: 408 out of 500
# Path: 409 out of 500
# Path: 410 out of 500
# Path: 411 out of 500
# Path: 412 out of 500
# Path: 413 out of 500
# Path: 414 out of 500
# Path: 415 out of 500
# Path: 416 out of 500
# Path: 417 out of 500
# Path: 418 out of 500
# Path: 419 out of 500
# Path: 420 out of 500
# Path: 421 out of 500
# Path: 422 out of 500
# Path: 423 out of 500
# Path: 424 out of 500
# Path: 425 out of 500
# Path: 426 out of 500
# Path: 427 out of 500
# Path: 428 out of 500
# Path: 429 out of 500
# Path: 430 out of 500
# Path: 431 out of 500
# Path: 432 out of 500
# Path: 433 out of 500
# Path: 434 out of 500
# Path: 435 out of 500
# Path: 436 out of 500
# Path: 437 out of 500
# Path: 438 out of 500
# Path: 439 out of 500
# Path: 440 out of 500
# Path: 441 out of 500
# Path: 442 out of 500
# Path: 443 out of 500
# Path: 444 out of 500
# Path: 445 out of 500
# Path: 446 out of 500
# Path: 447 out of 500
# Path: 448 out of 500
# Path: 449 out of 500
# Path: 450 out of 500
# Path: 451 out of 500
# Path: 452 out of 500
# Path: 453 out of 500
# Path: 454 out of 500
# Path: 455 out of 500
# Path: 456 out of 500
# Path: 457 out of 500
# Path: 458 out of 500
# Path: 459 out of 500
# Path: 460 out of 500
# Path: 461 out of 500
# Path: 462 out of 500
# Path: 463 out of 500
# Path: 464 out of 500
# Path: 465 out of 500
# Path: 466 out of 500
# Path: 467 out of 500
# Path: 468 out of 500
# Path: 469 out of 500
# Path: 470 out of 500
# Path: 471 out of 500
# Path: 472 out of 500
# Path: 473 out of 500
# Path: 474 out of 500
# Path: 475 out of 500
# Path: 476 out of 500
# Path: 477 out of 500
# Path: 478 out of 500
# Path: 479 out of 500
# Path: 480 out of 500
# Path: 481 out of 500
# Path: 482 out of 500
# Path: 483 out of 500
# Path: 484 out of 500
# Path: 485 out of 500
# Path: 486 out of 500
# Path: 487 out of 500
# Path: 488 out of 500
# Path: 489 out of 500
# Path: 490 out of 500
# Path: 491 out of 500
# Path: 492 out of 500
# Path: 493 out of 500
# Path: 494 out of 500
# Path: 495 out of 500
# Path: 496 out of 500
# Path: 497 out of 500
# Path: 498 out of 500
# Path: 499 out of 500
# [Parallel(n_jobs=-1)]: Done  70 out of  70 | elapsed:   41.1s finished

# %%
#predicting y values based on test set
y_pred_enet = enmodel.predict(Xs_test)
sns.jointplot(y_test,y_pred_enet, kind='reg').set_axis_labels('Actual Sales Price', 'Predicted Sales Price from Elastic Net Regression')
# Out:
# C:\Users\yitaris\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
fig,ax = plt.subplots(figsize = (10,5))
impt_feat(enmodel.coef_, X_test).abs().sort_values().tail(20).plot.barh()
plt.title('Top absolute coefficients - Highest impact on predicted prices')
# Out:
# Text(0.5,1,'Top absolute coefficients - Highest impact on predicted prices')

# %%
print("Best alpha:", enmodel.alpha_)
print("l1 Ratio chosen:", enmodel.l1_ratio_)
print("Intercept:", enmodel.intercept_)
score = enmodel.score(Xs_test, y_test)
print("R2 Score:", score)
# Out:
# Best alpha: 0.2762130062708075
# l1 Ratio chosen: 1.0
# Intercept: 418822.4347507183
# R2 Score: 0.8379797701713851

# %% [markdown]
# ### 4. Random Forest Regressor Model

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV

# %%
rfr = RandomForestRegressor()

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 10, stop = 200, num = 10)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

# Random search of parameters, using 3 fold cross validation, 
# search across 100 different combinations, and use all available cores
rf_random = RandomizedSearchCV(estimator = rfr, param_distributions = random_grid, n_iter = 100, cv = 3, verbose=2, random_state=28, n_jobs = 4)

# %%
rf_random.fit(X_train, y_train)
rf_random.best_params_
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  33 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=4)]: Done 154 tasks      | elapsed: 36.1min
# [Parallel(n_jobs=4)]: Done 300 out of 300 | elapsed: 77.4min finished
# {'n_estimators': 200,
#  'min_samples_split': 2,
#  'min_samples_leaf': 2,
#  'max_features': 'auto',
#  'max_depth': 70,
#  'bootstrap': True}

# %%
#Evaluating model with best parameters
rfr = RandomForestRegressor(n_estimators = 200, min_samples_leaf = 2, max_depth = 70, random_state = 28)
rfmodel = rfr.fit(X_train, y_train)
rfmodel.score(X_test, y_test)
# Out:
# 0.9454216067419827

# %%
fig,ax = plt.subplots(figsize = (10,5))
impt_feat(rfmodel.feature_importances_, X_test).sort_values().tail(20).plot.barh()
plt.title('Top important features - Highest impact on predicted prices')
# Out:
# Text(0.5,1,'Top important features - Highest impact on predicted prices')

# %%
enet_top = impt_feat(enmodel.coef_, X_test).abs().sort_values(ascending=False).head(20).index
rf_top = impt_feat(rfmodel.feature_importances_, X_test).sort_values(ascending=False).head(20).index

# %%
#comparisons
compare_features = pd.DataFrame({'Ranking':range(1,21), 'Elastic Net': enet_top, 'Random Forest Regressor': rf_top })
compare_features
# Out:
#     Ranking          Elastic Net Random Forest Regressor
# 0         1       floor_area_sqm          floor_area_sqm
# 1         2  lease_commence_date     lease_commence_date
# 2         3       town_WOODLANDS        town_BUKIT MERAH
# 3         4   town_CHOA CHU KANG            storey_range
# 4         5     town_JURONG WEST        flat_type_4 ROOM
# 5         6        town_SENGKANG         town_QUEENSTOWN
# 6         7       town_SEMBAWANG         remaining_lease
# 7         8         town_PUNGGOL             town_BISHAN
# 8         9   town_BUKIT PANJANG          town_WOODLANDS
# 9        10          town_YISHUN    town_KALLANG/WHAMPOA
# 10       11     town_BUKIT MERAH          town_TOA PAYOH
# 11       12         storey_range          gdp_per_capita
# 12       13       town_PASIR RIS       town_CENTRAL AREA
# 13       14      town_QUEENSTOWN            town_GEYLANG
# 14       15         town_HOUGANG           town_CLEMENTI
# 15       16      flat_model_DBSS         flat_model_DBSS
# 16       17     town_BUKIT BATOK      town_MARINE PARADE
# 17       18        town_TAMPINES           town_SENGKANG
# 18       19   town_MARINE PARADE        town_BUKIT TIMAH
# 19       20          town_BISHAN      town_CHOA CHU KANG

# %%
#Common features agreed on by both models
common = []
for n in enet_top:
    if n in rf_top:
        common.append(n)
common
# Out:
# ['floor_area_sqm',
#  'lease_commence_date',
#  'town_WOODLANDS',
#  'town_CHOA CHU KANG',
#  'town_SENGKANG',
#  'town_BUKIT MERAH',
#  'storey_range',
#  'town_QUEENSTOWN',
#  'flat_model_DBSS',
#  'town_MARINE PARADE',
#  'town_BISHAN']

# %%
#Unique features picked by each model not present in the other model
def find_unique(top_list):
    unique = []
    for n in top_list:
        if n not in common:
            unique.append(n)
    return unique

# %%
find_unique(enet_top)
# Out:
# ['town_JURONG WEST',
#  'town_SEMBAWANG',
#  'town_PUNGGOL',
#  'town_BUKIT PANJANG',
#  'town_YISHUN',
#  'town_PASIR RIS',
#  'town_HOUGANG',
#  'town_BUKIT BATOK',
#  'town_TAMPINES']

# %%
find_unique(rf_top)
# Out:
# ['flat_type_4 ROOM',
#  'remaining_lease',
#  'town_KALLANG/WHAMPOA',
#  'town_TOA PAYOH',
#  'gdp_per_capita',
#  'town_CENTRAL AREA',
#  'town_GEYLANG',
#  'town_CLEMENTI',
#  'town_BUKIT TIMAH']

# %% [markdown]
# #### Insights:
# Both approaches yielded similar results, with the Random Forest Regressor achieving a higher R2 score on the test set at 94.5% compared to Elastic Net at 83.8%. Both agree that the most critical factors affecting house prices are floor area and lease commence date. Elastic Net model seems to favor different towns as having a higher impact on prices, while the Random Forest Regressor is able to pick up other factors like flat type, remaining_lease, and gdp per capita (the economic indicator).

# %% [markdown]
# ### 4. Time Series Analysis and Predictions

# %%
from statsmodels.tsa.stattools import acf, pacf, adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARMA, ARIMA

from sklearn.metrics import r2_score

# %%
#For time series analysis we'll look at the median prices of all flats in singapore over time
series = data.groupby(['date'])['resale_price'].median()

# %%
series = series.reset_index()
series['date'] = pd.to_datetime(series['date'])
series.set_index('date', inplace = True, drop=True)

# %%
fig,ax = plt.subplots(figsize=(15,7))
series.plot.line(ax=ax)
plt.title('Median Resale Prices of flats over time', fontsize = 15)
plt.show()

# %%
decomposition = seasonal_decompose(series['resale_price'], freq=12)  
fig = plt.figure()  
fig = decomposition.plot()  
fig.set_size_inches(12, 8)

# %%
fig, ax = plt.subplots(nrows = 2, ncols =1, figsize=(8,5))
plot_acf(series['resale_price'], lags=30, ax=ax[0])
plot_pacf(series['resale_price'], lags=30, ax=ax[1])
plt.suptitle('Autocorrelation for Resale Price',fontsize = 16)
plt.show()
# Out:
# C:\Users\yitaris\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1283: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %%
def test_stationarity(timeseries):

    # Determining rolling statistics:
    rolmean = timeseries.rolling(window=12, center=False).mean()
    rolstd = timeseries.rolling(window=12, center=False).std()

    # Plotting rolling statistics:
    fig = plt.figure(figsize=(12, 8))
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show()
    
    # Performing a Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
test_stationarity(series['resale_price'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.283600
# p-value                         0.636642
# #Lags Used                      1.000000
# Number of Observations Used    80.000000
# Critical Value (1%)            -3.514869
# Critical Value (5%)            -2.898409
# Critical Value (10%)           -2.586439
# dtype: float64

# %% [markdown]
# #### Using ARIMA for forecasting

# %%
train = series[series.index.year<2017]
test = series[series.index.year>2016]

# %%
#Using ARIMA Model for forecast
model = ARIMA(train['resale_price'], (13,1,1))
results = model.fit()
print(results.summary())

#plot residuals
residuals = pd.DataFrame(results.resid)
residuals.plot()
# Out:
# C:\Users\yitaris\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\yitaris\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:         D.resale_price   No. Observations:                   58
# Model:                ARIMA(13, 1, 1)   Log Likelihood                -579.751
# Method:                       css-mle   S.D. of innovations           5259.275
# Date:                Tue, 18 Dec 2018   AIC                           1191.502
# Time:                        17:01:18   BIC                           1224.469
# Sample:                    03-01-2012   HQIC                          1204.343
#                          - 12-01-2016
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                   202.1188    974.678      0.207      0.837   -1708.215    2112.453
# ar.L1.D.resale_price     -0.2896      0.641     -0.452      0.654      -1.546       0.967
# ar.L2.D.resale_price      0.0214      0.179      0.120      0.905      -0.329       0.372
# ar.L3.D.resale_price      0.1141      0.137      0.834      0.409      -0.154       0.382
# ar.L4.D.resale_price      0.1886      0.154      1.225      0.227      -0.113       0.490
# ar.L5.D.resale_price      0.0262      0.175      0.150      0.882      -0.317       0.370
# ar.L6.D.resale_price     -0.0909      0.137     -0.663      0.511      -0.360       0.178
# ar.L7.D.resale_price     -0.0035      0.153     -0.023      0.982      -0.303       0.296
# ar.L8.D.resale_price      0.1122      0.142      0.791      0.433      -0.166       0.390
# ar.L9.D.resale_price     -0.0859      0.161     -0.532      0.597      -0.402       0.231
# ar.L10.D.resale_price     0.1198      0.145      0.828      0.412      -0.164       0.403
# ar.L11.D.resale_price    -0.0488      0.175     -0.279      0.782      -0.392       0.294
# ar.L12.D.resale_price     0.0632      0.161      0.392      0.697      -0.253       0.379
# ar.L13.D.resale_price     0.1207      0.146      0.829      0.412      -0.165       0.406
# ma.L1.D.resale_price      0.1007      0.632      0.159      0.874      -1.139       1.340
#                                     Roots
# ==============================================================================
#                    Real          Imaginary           Modulus         Frequency
# ------------------------------------------------------------------------------
# AR.1             1.1169           -0.0000j            1.1169           -0.0000
# AR.2             1.0403           -0.5567j            1.1799           -0.0782
# AR.3             1.0403           +0.5567j            1.1799            0.0782
# AR.4             0.6728           -1.0356j            1.2349           -0.1583
# AR.5             0.6728           +1.0356j            1.2349            0.1583
# AR.6             0.0404           -1.1510j            1.1517           -0.2444
# AR.7             0.0404           +1.1510j            1.1517            0.2444
# AR.8            -0.3882           -1.0853j            1.1526           -0.3047
# AR.9            -0.3882           +1.0853j            1.1526            0.3047
# AR.10           -0.8675           -0.6463j            1.0818           -0.3981
# AR.11           -0.8675           +0.6463j            1.0818            0.3981
# AR.12           -1.1108           -0.0000j            1.1108           -0.5000
# AR.13           -1.5256           -0.0000j            1.5256           -0.5000
# MA.1            -9.9345           +0.0000j            9.9345            0.5000
# ------------------------------------------------------------------------------

# %%
def plot_series(model,df,train,test,col):
    predictions = model.predict()
    full_pred = train[col].values[0]+np.cumsum(model.fittedvalues)
    
    #Graph
    fig, ax = plt.subplots(figsize=(12,5))
    ax.plot(train.index[1:], full_pred, lw=2, color='grey', ls='dashed',label = 'in-sample prediction')
    ax.plot(df.index, df[col], lw=2, color='darkred')
    ax.plot(test.index, model.forecast(steps=len(test))[0], lw=2, color='blue',label = 'forecast')
    ax.plot(test.index, model.forecast(steps=len(test))[2], lw=2, color='blue', ls='dashed',label = 'forecast')
    plt.legend()
    plt.title('Resale Price predictions on 2017-2018')

# %%
plot_series(results, series, train, test, 'resale_price')

# %% [markdown]
# #### Using LSTM for forecasting

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras import backend as K
from sklearn.preprocessing import MinMaxScaler

# %%
series['diff'] = series['resale_price'].diff(1)
series.dropna(inplace=True) #drops the first NaN value after differencing.

price = series[['diff']]
mms = MinMaxScaler(feature_range=(-1, 1))
price = mms.fit_transform(price)

series['diff'].plot()

# %%
#Splitting into 50% train-test split
train_size = int(len(price) * 0.50)
test_size = len(price) - train_size
print(len(price), train_size, test_size)

train, test = price[0:train_size,:], price[train_size:len(price),:]
# Out:
# 81 40 41

# %%
def create_data(timeseries, lag=1, as_array=True):
    if not isinstance(timeseries, pd.Series):
        timeseries = pd.Series(timeseries.ravel())
    y = timeseries[lag:]
    X = pd.DataFrame({'lag'+str(lag-i):timeseries.shift(-i) for i in range(0, lag)}).dropna().iloc[:-1, :]
    if not as_array:
        return X, y
    else:
        return X.values, y.values

# %%
def lstm_prediction_plotter(model,trainX,testX,orig_data):
    model.reset_states()
    trainPredict = model.predict(trainX)
    model.reset_states()
    testPredict = model.predict(testX)
    model.reset_states()

    # shift train predictions for plotting
    trainPredictPlot = np.empty_like(orig_data)
    trainPredictPlot[:, :] = np.nan
    trainPredictPlot[lag:len(trainPredict)+lag, :] = trainPredict

    # shift test predictions for plotting
    testPredictPlot = np.empty_like(orig_data)
    testPredictPlot[:, :] = np.nan
    testPredictPlot[-len(testPredict)-1:-1, :] = testPredict


    fig, ax = plt.subplots(ncols=1, nrows =2, figsize = (12,8))

    ax[0].plot(orig_data,label='original data')
    ax[0].plot(trainPredictPlot,label='in_sample prediction')
    ax[0].plot(testPredictPlot,label='out_sample prediction')
    ax[1].set_title('Graph of all data')
    ax[0].set_xticks([])
    ax[0].legend()

    ax[1].plot(orig_data[250:],label='original data')
    ax[1].plot(trainPredictPlot[250:],label='in_sample prediction')
    ax[1].plot(testPredictPlot[250:],label='out_sample prediction')
    ax[1].set_title('Zoom in to tested portion')
    ax[1].set_xticks([])
    ax[1].legend()
    plt.suptitle('Graph of prediction vs actual data', fontsize = 16);

# %%
def lstm_obtain_r2(model,trainX,testX,trainY,testY):
    model.reset_states()
    trainPredict = model.predict(trainX)
    model.reset_states()
    testPredict = model.predict(testX)
    model.reset_states()
    
    train_r2 = r2_score(trainY, trainPredict)
    print('train_r2',train_r2) 
    test_r2 = r2_score(testY[:-1], testPredict[1:])
    print('test_r2',test_r2)
    return [train_r2,test_r2]

# %%
lag = 1
trainX, trainY = create_data(train, lag)
testX, testY = create_data(test, lag)
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
K.clear_session()

model = Sequential()
model.add(LSTM(4, input_shape=(None, lag)))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')
with tf.device('/cpu:0'):
    model.fit(trainX, trainY, epochs=20, batch_size=1, verbose=1)
lstm_prediction_plotter(model,trainX,testX,mean_resale_px)
score = lstm_obtain_r2(model,trainX,testX,trainY,testY)
lstm_summary = add_lstm_score('mean_resale_px','1 layer| 4 nodes | optimizer = "adam"',score,[])
# Out:
# Epoch 1/20
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-152-07a19eec0ee1> in <module>()
#       7 model.compile(loss='mean_squared_error', optimizer='adam')
#       8 with tf.device('/cpu:0'):
# ----> 9     model.fit(trainX, trainY, epochs=20, batch_size=1, verbose=1)
#      10 lstm_prediction_plotter(model,trainX,testX,mean_resale_px)
#      11 score = lstm_obtain_r2(model,trainX,testX,trainY,testY)
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# ~\Anaconda3\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# ~\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2695
#    2696     def __call__(self, inputs):
# -> 2697         if hasattr(get_session(), '_make_callable_from_options'):
#    2698             if py_any(is_sparse(x) for x in self.inputs):
#    2699                 if py_any(is_tensor(x) for x in inputs):
#
# ~\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in get_session()
#     184                 config = tf.ConfigProto(intra_op_parallelism_threads=num_thread,
#     185                                         allow_soft_placement=True)
# --> 186             _SESSION = tf.Session(config=config)
#     187         session = _SESSION
#     188     if not _MANUAL_VAR_INIT:
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in __init__(self, target, graph, config)
#    1549
#    1550     """
# -> 1551     super(Session, self).__init__(target, graph, config=config)
#    1552     # NOTE(mrry): Create these on first `__enter__` to avoid a reference cycle.
#    1553     self._default_graph_context_manager = None
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in __init__(self, target, graph, config)
#     674     try:
#     675       # pylint: disable=protected-access
# --> 676       self._session = tf_session.TF_NewSessionRef(self._graph._c_graph, opts)
#     677       # pylint: enable=protected-access
#     678     finally:
#
# InternalError: cudaGetDevice() failed. Status: CUDA driver version is insufficient for CUDA runtime version
